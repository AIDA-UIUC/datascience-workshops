# %% [markdown]
# <a href="https://colab.research.google.com/github/AIDA-UIUC/datascience-workshops/blob/master/07_webscraping/07_REST_Webscraping_(Solution).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AIDA Data Science Workshop #7
#
# Today we'll be learning about HTTP and web scraping!

# %%
# some package installation
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.6/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (1.24.3)

# %% [markdown]
# ### What is HTTP?
# -
# HTTP is a set of protocols designed to enable communication between clients and servers. A web browser may be the client, and an application on a computer that hosts a web site may be the server.
#
# ### What is a GET request?
# - One of the most common requests used to "GET" data from a specific source
#
# ### What is a POST request?
# - Another commonly used request that allows the user to send or "POST" data to a specific source
#
# ### What is a DELETE request?
# - Allows the user to "DELETE" from a specific source
#
#
# ### More information here:
# https://www.w3schools.com/tags/ref_httpmethods.asp

# %% [markdown]
# Today we will only be working with a GET request.
#
# (Simple demo of HTTP GET and POST requests)

# %% [markdown]
# ## Anatomy of an HTTP request
# ```
# GET /httpgallery/introduction/ HTTP/1.1
# Accept: */*
# Accept-Language: en-gb
# Accept-Encoding: gzip, deflate
# User-Agent: Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko
# Host: www.httpwatch.com
# Connection: Keep-Alive
# ```

# %% [markdown]
# ##Webscraping with BS4

# %%
# We'll start with a pretty simple HTML document that you can see below
from IPython.core.display import display, HTML

html_doc = """
<html>
    <head>
        <title>
            The Dormouse's story
        </title>
        </head>
    <body>

    <p class="title">
        <b>
            The Dormouse's story
        </b>
    </p>

    <p class="story">
        Once upon a time there were three little sisters; and their names were
        <a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
        <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
        <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
        and they lived at the bottom of a well.
    </p>

    <p class="story">
        This is another story p block
    </p>

    </body>
</html>
"""

display(HTML(html_doc))
# Out:
# <html>
#     <head>
#         <title>
#             The Dormouse's story
#         </title>
#         </head>
#     <body>
#
#     <p class="title">
#         <b>
#             The Dormouse's story
#         </b>
#     </p>
#
#     <p class="story">
#         Once upon a time there were three little sisters; and their names were
#         <a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
#         <a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
#         <a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
#         and they lived at the bottom of a well.
#     </p>
#
#     <p class="story">
#         This is another story p block
#     </p>
#
#     </body>
# </html>

# %%
# In core Python, you could do something like the following if you wanted to get the title of the html_doc...
## note that html_doc is a string so we can call .find() on it

print(html_doc[html_doc.find("<title>") + len("<title>"): html_doc.find("</title")])

# This is pretty confusing to read right? And really too much effort on us programmers
# Out:
#             The Dormouse's story

# %% [markdown]
# #### So if using core Python is too much work, what can we use?

# %%
# Beautiful Soup!
from bs4 import BeautifulSoup

# Create a soup object!

soup = BeautifulSoup(html_doc, 'html.parser')

print(soup) #let's print out this new HTML soup and see what it looks like
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-525d6f3bd24f> in <module>()
#       4 # Create a soup object!
#       5
# ----> 6 soup = BeautifulSoup(html_doc, 'html.parser')
#       7
#       8 print(soup) #let's print out this new HTML soup and see what it looks like
#
# NameError: name 'html_doc' is not defined

# %% [markdown]
# That's pretty ugly right? Luckily, this new soup object we've created has a built-in "pretty print" function you can call like below:

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
#         and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    This is another story p block
#   </p>
#  </body>
# </html>

# %% [markdown]
# Great! That's much easier to read but it's still just raw HTML text and no one likes that...
#
# How do we use BS4 to navigate the soup?

# %%
# Let's take the previous example of finding the title of the HTML doc
# How do we do this in BS4?

print(soup.title)
# Out:
# <title>
#             The Dormouse's story
#         </title>

# %%
# Hmm, it's still got those weird <title> brackets

print(soup.title.get_text()) # Perfect!
# Out:
#             The Dormouse's story

# %% [markdown]
# Note that BS4 creates objects for every kind of HTML tag: "a", "p", "title", "div", etc. so be aware of what you're actually getting when you try to get something from your HTML soup!

# %% [markdown]
# ### **STOP!** A bit of legality before we start looking at actual websites...
#
# Many sites have begun to implement a `robots.txt`, which is a file located on the website specifying how robots can access their site. As a data scientist, or more specifically, a `high speed data access machine`, we have to respect the rules of these websites. Some sites are even illegal to scrape due to privacy concerns.
#
# Luckily, if the site implements a robots.txt, which we can access through `/robots.txt`, then we can inspect it to see if we are allowed to do what we want to do. (Read more about it here: http://www.robotstxt.org/)

# %%
# example robots.txt
import requests

r = requests.get("https://www.tripadvisor.com/robots.txt")
print(r.text)
# Out:
# # Hi there,
# #
# # If you're sniffing around this file, and you're not a robot, we're looking to meet curious folks such as yourself.
# #
# # Think you have what it takes to join the best white-hat SEO growth hackers on the planet?
# #
# # Run - don't crawl - to apply to join TripAdvisor's elite SEO team
# #
# # Email seoRockstar@tripadvisor.com
# #
# # Or visit https://careers.tripadvisor.com/search-results?keywords=seo
# #
# #
# Sitemap: https://www.tripadvisor.com/sitemap/2/en_US/sitemap_en_US_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/2/en_US/sitemap_en_US_location_photo_direct_link_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/2/en_US/sitemap_en_US_show_user_reviews_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/vr/en_US/sitemap_en_US_rentals_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/vr/en_US/sitemap_en_US_vacation_rental_review_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/vr/en_US/sitemap_en_US_vacation_rentals_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/vr/en_US/sitemap_en_US_vacation_rentals_near_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/vr/en_US/sitemap_en_US_vr_show_user_reviews_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/att/en_US/sitemap_en_US_attractions_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/att/en_US/sitemap_en_US_attraction_review_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/att/en_US/sitemap_en_US_attraction_product_review_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/att/en_US/sitemap_en_US_attractions_near_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/att/en_US/sitemap_en_US_attraction_tours_and_tickets_index.xml
# Sitemap: https://www.tripadvisor.com/sitemap/2/en_US/sitemap_en_US_lpdltest_index.xml
# User-Agent: *
# Disallow: /5349
# Disallow: /AcceptDeferredTermsAndConditions
# Disallow: /AccessTokenLogin
# Disallow: /AccommodationCrossSells
# Disallow: /AccommodationTips
# Disallow: /AccountMerge
# Disallow: /ActionRecord
# Disallow: /ActLikeAnOwner
# Disallow: /AddForumUser
# Disallow: /AddListing
# Disallow: /AdRequestEventLogApi
# Disallow: /AdServlet
# Disallow: /AdsManager
# Disallow: /AeroflotCampaignRegistration
# Disallow: /AffiliateWidgets
# Disallow: /AgencySetupAjax
# Disallow: /AirAsiaRegistration
# Disallow: /AirlineRegistration
# Disallow: /AirlineTips
# Disallow: /AirportFromGeoAjax
# Disallow: /AirportIP
# Disallow: /AirWatchAjaxHandler
# Disallow: /AirWatchAlertDhtmlPopup
# Disallow: /AirWatchSubscriptionAjax
# Disallow: /AirWatchSubscriptionWidget
# Disallow: /AlfursanRegistration
# Disallow: /AllReviews
# Disallow: /AnalyticsSuite
# Disallow: /ANAMileRegistration
# Disallow: /AnswersAjax
# Disallow: /api
# Disallow: /APIAccessSupport
# Disallow: /AppleMapsAction
# Disallow: /apps
# Disallow: /AsHeardOn
# Disallow: /AsiaMilesRegistration
# Disallow: /AsianaAirlineRegistration
# Disallow: /Attraction_Products
# Disallow: /AttractionAmendTravelDate
# Disallow: /AttractionBookingApi
# Disallow: /AttractionBookingDetails
# Disallow: /AttractionBookingProfile
# Disallow: /AttractionCancelBooking
# Disallow: /AttractionCommerceAjax
# Disallow: /AttractionOperatorReview
# Disallow: /AttractionProductDetail
# Disallow: /AttractionProductsAjax
# Disallow: /AttractionsAjax
# Disallow: /AuthCheck
# Disallow: /AuthorizeAgency
# Disallow: /avis
# Disallow: /b2bauth
# Disallow: /B2BClickTracking
# Disallow: /BAEmailConfirmation
# Disallow: /BALinkImpressionTracking
# Disallow: /BeachSweeps
# Disallow: /BetterBySea
# Disallow: /bewerten
# Disallow: /BICompetitorSet
# Disallow: /BillingAndPayments
# Disallow: /BillingDetail
# Disallow: /BillingInvoiceFile
# Disallow: /BLImpRecord
# Disallow: /blog/wp-admin/
# Disallow: /BlogPageSubmit
# Disallow: /BlPromoOptOut
# Disallow: /BookingConfirmation
# Disallow: /BookingRequest
# Disallow: /Bookings
# Disallow: /BrandOwners
# Disallow: /BusinessListingsAjax
# Disallow: /bzzagent
# Disallow: /CampaignConfigAjax
# Disallow: /CampaignConfiguration
# Disallow: /CampaignManagement
# Disallow: /CampaignOptions
# Disallow: /CancelBooking
# Disallow: /CarsComparePartners
# Disallow: /CauseTeaserPopup
# Disallow: /cds/media
# Disallow: /CDSimp
# Disallow: /Celebrate100Million
# Disallow: /CertificateOfExcellenceRequestSupport
# Disallow: /CheapFlightsCommerce
# Disallow: /CheapFlightsController
# Disallow: /CheapFlightsPartnerHandoff
# Disallow: /CheapFlightsPartnerPostHandoff
# Disallow: /CheapFlightsRecord
# Disallow: /CheapFlightsSearchDeals
# Disallow: /CheapFlightsSearchResults
# Disallow: /CheapFlightsSearchSeatGuru
# Disallow: /Civ
# Disallow: /Claim
# Disallow: /CMSImp
# Disallow: /cmsimp
# Disallow: /Commerce
# Disallow: /CommLCT
# Disallow: /CommPT
# Disallow: /CommunityAjax
# Disallow: /CommunityMapImage
# Disallow: /ConnectivityPartnerFAQ
# Disallow: /ConnectivityPartnerInfo
# Disallow: /ConnectivityPartnerSignup
# Disallow: /Contributions
# Disallow: /CookiePingback
# Disallow: /CookiePolicy
# Disallow: /CostPerClick
# Disallow: /CountryAjax
# Disallow: /Covid19Response
# Disallow: /CreateListing
# Disallow: /CruisesCommerce
# Disallow: /CruisesPartnerHandoff
# Disallow: /CuratedShelvesPreview
# Disallow: /CurationTool
# Disallow: /DangDangFirstPopup
# Disallow: /DaoDaoEtpassFirstPopup
# Disallow: /DaoDaoHomePageGeoHotelsTab
# Disallow: /DaoDaoPriceQuoteAjax
# Disallow: /DaoDaoReviewTeaserFirstPopup
# Disallow: /DaoDaoStaticVelocityPage
# Disallow: /Dashboard
# Disallow: /data
# Disallow: /DelayedLoad
# Disallow: /DeleteNotify
# Disallow: /DemandLoadAjax
# Disallow: /DepositResolution
# Disallow: /DestinationArticle
# Disallow: /DestinationGuideWidget
# Disallow: /DestinationReview
# Disallow: /Destinations
# Disallow: /DevMediaRedirector
# Disallow: /DhtmlPopup
# Disallow: /DisplayMap
# Disallow: /DynamicPlacementAjax
# Disallow: /EmailHotel
# Disallow: /EmailMap
# Disallow: /EmailMemberRegistration
# Disallow: /EmailSpellCheckJson
# Disallow: /EmbeddedContent
# Disallow: /ErrorPage
# Disallow: /EtihadGuestRegistration
# Disallow: /EventDates
# Disallow: /ExitWindow
# Disallow: /ExpandedUserReviews
# Disallow: /ExperiencesAffiliateRedirect
# Disallow: /ExperiencesInsights/?s
# Disallow: /ExternalExitWindow
# Disallow: /ExternalIdMap
# Disallow: /FacebookConnect
# Disallow: /FacebookRedirect
# Disallow: /FareCalendar
# Disallow: /FavoriteReviewManagement
# Disallow: /Featured
# Disallow: /FilterState
# Disallow: /FinishAppInstall
# Disallow: /Flights?
# Disallow: /FlightsCommerce
# Disallow: /FlightsComparePartners
# Disallow: /FlightsController
# Disallow: /FlightsPricelink
# Disallow: /FlightsRecord
# Disallow: /FlipKeyIdMap
# Disallow: /FlyingBlueRegistration
# Disallow: /ForgotPassword
# Disallow: /ForumFAQ
# Disallow: /ForumPostPreview
# Disallow: /ForumRedirect
# Disallow: /ForumSetSortCookie
# Disallow: /ForumSignIn
# Disallow: /forumTeaser
# Disallow: /ForumVote
# Disallow: /FreeTools
# Disallow: /FullRedirect
# Disallow: /GARecord
# Disallow: /GarudaMilesRegistration
# Disallow: /GeneralSupport
# Disallow: /GermanwingsPromo
# Disallow: /GermanwingsRegistration
# Disallow: /GetListedAjaxGeneral
# Disallow: /GetListedLightbox
# Disallow: /GetListedUpdateAttraction
# Disallow: /GetListedUpdateEatery
# Disallow: /GetMobileApp
# Disallow: /GMapsLocationController
# Disallow: /GOffer
# Disallow: /GOWidget
# Disallow: /Gpits
# Disallow: /GPointCampaign
# Disallow: /GreenLeaderAjax
# Disallow: /GreenLeadersProxy
# Disallow: /GroupHomeApi
# Disallow: /GroupHotelCommerce
# Disallow: /GroupManagementCenter
# Disallow: /GSSAjax
# Disallow: /GuestExperience
# Disallow: /GuideAjax
# Disallow: /GuideEditor
# Disallow: /GuideRatingAjax
# Disallow: /GuideRequested
# Disallow: /GuideRequestor
# Disallow: /HACAffiliate
# Disallow: /HandleHotelSuperPortal
# Disallow: /HelpProxy
# Disallow: /Home-
# Disallow: /Hotel_ReviewHAC
# Disallow: /HotelBookingController
# Disallow: /HotelBookingRoomSelectionHtml
# Disallow: /HotelBookingRoomSelectionJson
# Disallow: /HotelGMCApi
# Disallow: /HotelHighlight
# Disallow: /HotelInterruptersAjax
# Disallow: /HotelsManageListing
# Disallow: /HotelsManagementCenter
# Disallow: /HotelsProductCart
# Disallow: /HotelWatchAjax
# Disallow: /HRMConnect
# Disallow: /IBCommerce
# Disallow: /ImpressionRecord
# Disallow: /ImproveListing
# Disallow: /Inbox
# Disallow: /IndiaPlazaFirstPopup
# Disallow: /IndiaTimesFirstPopup
# Disallow: /InfoCenter
# Disallow: /InitializeSession
# Disallow: /InlineReviewerCta
# Disallow: /InstantBooking-
# Disallow: /InstantBookingManagement
# Disallow: /InstantBookingSignup
# Disallow: /IpadInterstitial
# Disallow: /IPhoneMemberActions
# Disallow: /JALMileRegistration
# Disallow: /JPMilesRegistration
# Disallow: /js/
# Disallow: /js2/
# Disallow: /js3/
# Disallow: /JSErrorRecord
# Disallow: /JsonServiceController
# Disallow: /JustForYouGuide
# Disallow: /LandingPage
# Disallow: /LangRedirect
# Disallow: /LANPASSRegistration
# Disallow: /Leaderboard
# Disallow: /LightSubscriptionCenter
# Disallow: /LikeButtonClicked
# Disallow: /LinkGenerator
# Disallow: /ListingQuestionsAjax
# Disallow: /LithiumEmptyPage
# Disallow: /LithiumPageNotFound
# Disallow: /LNAjax
# Disallow: /LocationPhotoAlbum
# Disallow: /LocationPhotosInline
# Disallow: /LocationPhotosLightbox
# Disallow: /LocationPhotosSearch
# Disallow: /LocationTab
# Disallow: /LocationWidget
# Disallow: /LogMediaClick
# Disallow: /MachineTranslation
# Disallow: /ManageListing
# Disallow: /ManagementCenter
# Disallow: /ManageOwnersTopReasonsApi
# Disallow: /ManagePhotos
# Disallow: /ManageShopListingApi
# Disallow: /ManageShopping
# Disallow: /ManageStoryboard
# Disallow: /ManageUserAccess
# Disallow: /MapEmbed
# Disallow: /media/0000
# Disallow: /media/advertorials
# Disallow: /media/attractions-splice-test-spp
# Disallow: /media/bl-video
# Disallow: /media/BookingThumbnails
# Disallow: /media/careers
# Disallow: /media/daodao/photo-f
# Disallow: /media/daodao/photo-l
# Disallow: /media/daodao/photo-t
# Disallow: /media/daodao/video-t
# Disallow: /media/daodao/video-v
# Disallow: /media/fbavatar
# Disallow: /media/forums
# Disallow: /media/ja-content-thumbs
# Disallow: /media/jwplayer
# Disallow: /media/mktg
# Disallow: /media/mobile
# Disallow: /media/oyster
# Disallow: /media/photo-a
# Disallow: /media/photo-f
# Disallow: /media/photo-g
# Disallow: /media/photo-l
# Disallow: /media/photo-o
# Disallow: /media/photo-t
# Disallow: /media/photo-w
# Disallow: /media/ProviderThumbnails
# Disallow: /media/solutions
# Disallow: /media/string
# Disallow: /media/t4b
# Disallow: /media/ta
# Disallow: /media/TALSO.swf
# Disallow: /media/test
# Disallow: /media/thirdpartyflash
# Disallow: /media/tmp
# Disallow: /media/tourism-content
# Disallow: /media/travelpod-roll.flv
# Disallow: /media/TUIThumbnails
# Disallow: /media/unesco
# Disallow: /media/vr-geo-photo-j
# Disallow: /media/vr-geo-photo-l
# Disallow: /media/vr-geo-photo-m
# Disallow: /media/vr-geo-photo-s
# Disallow: /media/vr-ha-splice
# Disallow: /media/vr-nifty-headers
# Disallow: /media/vr-photo-j
# Disallow: /media/vr-photo-l
# Disallow: /media/vr-photo-m
# Disallow: /media/vr-photo-o
# Disallow: /media/vr-photo-q
# Disallow: /media/vr-photo-s
# Disallow: /media/vr-photo-test-j
# Disallow: /media/vr-photo-test-l
# Disallow: /media/vr-photo-test-m
# Disallow: /media/vr-photo-test-o
# Disallow: /media/vr-photo-test-q
# Disallow: /media/vr-photo-test-s
# Disallow: /media/vr-photos
# Disallow: /media/vr-splice-l
# Disallow: /media/vr-splice-m
# Disallow: /media/vr-splice-s
# Disallow: /media/vr-splice-test-j
# Disallow: /media/vr-splice-test-l
# Disallow: /media/vr-splice-test-m
# Disallow: /media/vr-splice-test-s
# Disallow: /MediaBadgeResponse
# Disallow: /MediaKit
# Disallow: /MediaVoting
# Disallow: /MemberAuditLogger
# Disallow: /MemberBenefitsPopup
# Disallow: /MemberContributionController
# Disallow: /MemberForgotPassword
# Disallow: /MemberOverlay
# Disallow: /MemberPassportStamps
# Disallow: /MemberPhotos
# Disallow: /MemberProfile
# Disallow: /MemberResetPassword
# Disallow: /members-
# Disallow: /MemberSubscribe
# Disallow: /MemberSubscriptionsController
# Disallow: /MemberTagsAjax
# Disallow: /MemberTravelMap
# Disallow: /Messages
# Disallow: /MessagingOptions
# Disallow: /MetaAirCalendarAjax
# Disallow: /MetaBestPriceCrossSellAjax
# Disallow: /MetaCheckRatesAjax
# Disallow: /MetaJsonAjax
# Disallow: /MetaPlacementAjax
# Disallow: /MetricsAjax
# Disallow: /mgo
# Disallow: /MicroMetaAjax
# Disallow: /MiniMetaCRAjax
# Disallow: /mobile
# Disallow: /MobileAddPoi
# Disallow: /MobileAddressLookupAjax
# Disallow: /MobileAdsManager
# Disallow: /MobileAeroflotBonus
# Disallow: /MobileAeroflotCampaignRegistration
# Disallow: /MobileAirAsia
# Disallow: /MobileAirlineDeals
# Disallow: /MobileAirlines
# Disallow: /MobileAirlineTips
# Disallow: /MobileAirport
# Disallow: /MobileAirwatch
# Disallow: /MobileAlfursan
# Disallow: /MobileANAMileCampaign
# Disallow: /MobileANAMileRegistration
# Disallow: /MobileApps
# Disallow: /MobileAsiaMiles
# Disallow: /MobileAsianaAirline
# Disallow: /MobileAttraction_Products
# Disallow: /MobileAttraction_Review
# Disallow: /MobileAttractionProductReview
# Disallow: /MobileAttractions
# Disallow: /MobileAttractionSearch
# Disallow: /MobileAttractionToursAndTickets
# Disallow: /MobileBookingConfirmationShare
# Disallow: /MobileBookingConfirmationSMSResponse
# Disallow: /MobileBookingCustomerSupport
# Disallow: /MobileBookingRequest
# Disallow: /MobileBookings
# Disallow: /MobileCampaignOptions
# Disallow: /MobileCancelBooking
# Disallow: /MobileCheapFlightsHome
# Disallow: /MobileCheapFlightsPartnerPostHandoff
# Disallow: /MobileCheapFlightsSearchResults
# Disallow: /MobileCheapFlightsSearchSeatGuru
# Disallow: /MobileCiv
# Disallow: /MobileContributions
# Disallow: /MobileCookie
# Disallow: /MobileEtihadGuest
# Disallow: /MobileEventRecord
# Disallow: /MobileFAQ
# Disallow: /MobileFareCalendar
# Disallow: /MobileFeaturedVacationRentals
# Disallow: /MobileFilters
# Disallow: /MobileFlights
# Disallow: /MobileFlyingBlue
# Disallow: /MobileFooter
# Disallow: /MobileForgotPassword
# Disallow: /MobileForumHome
# Disallow: /MobileForumRedirect
# Disallow: /MobileForumSetSortCookie
# Disallow: /MobileGarudaMiles
# Disallow: /MobileGetMobileApp
# Disallow: /MobileGuide
# Disallow: /MobileHacPerformancePingback
# Disallow: /MobileHeaderCss
# Disallow: /MobileHotelBookingAgreeToBook
# Disallow: /MobileHotelBookingAllRoomSelectionAjax
# Disallow: /MobileHotelBookingAuthorization
# Disallow: /MobileHotelBookingPaymentform
# Disallow: /MobileHotelBookingRecordThreatIdAjax
# Disallow: /MobileHotelBookingRoomDetail
# Disallow: /MobileHotelBookingRoomSelection
# Disallow: /MobileHotelBookingSuccess
# Disallow: /MobileHotelCancellationPolicy
# Disallow: /MobileHotelHighlight
# Disallow: /MobileImpressionRecord
# Disallow: /MobileImproveThisListing
# Disallow: /MobileJALMileCampaign
# Disallow: /MobileJALMileRegistration
# Disallow: /MobileJPMilesCampaign
# Disallow: /MobileJPMilesRegistration
# Disallow: /MobileJSErrorRecord
# Disallow: /MobileJson
# Disallow: /MobileJSONImpressionRecord
# Disallow: /MobileJustForYouGuide
# Disallow: /MobileLANPASS
# Disallow: /MobileListForums
# Disallow: /MobileLocalMaps
# Disallow: /MobileLocation
# Disallow: /MobileManageListing
# Disallow: /MobileManagementCenter
# Disallow: /MobileManagePhotos
# Disallow: /MobileMemberProfile
# Disallow: /MobileMemberResetPassword
# Disallow: /Mobilemembers
# Disallow: /MobileMobileReservation
# Disallow: /MobileMultiplusCampaign
# Disallow: /MobileMultiplusRegistration
# Disallow: /MobileMyBookingsDetail
# Disallow: /MobileMyBookingsVoucher
# Disallow: /MobileMyInbox
# Disallow: /MobileNativeCountrySettings
# Disallow: /MobileNativeCurrencySettings
# Disallow: /MobileNativeSettings
# Disallow: /MobileNearbyAttractions
# Disallow: /MobileNearbyHotels
# Disallow: /MobileNearbyLander
# Disallow: /MobileNearbyRestaurants
# Disallow: /MobileNewsletterSignOut
# Disallow: /MobileNewTopic
# Disallow: /MobileNokiaLauncher
# Disallow: /MobileOKPlus
# Disallow: /MobileOlaCabsEstimateAjax
# Disallow: /MobileOwnerVerifyLocation
# Disallow: /MobilePageviewRecord
# Disallow: /MobilePasswordReset
# Disallow: /MobilePaybackCampaign
# Disallow: /MobilePaybackRegistration
# Disallow: /MobilePayment
# Disallow: /MobilePhotoUpload
# Disallow: /MobilePOITagging
# Disallow: /MobilePostPhoto
# Disallow: /MobilePostReply
# Disallow: /MobilePromotionDetail
# Disallow: /MobileQueryBBox
# Disallow: /MobileRac
# Disallow: /MobileRecent
# Disallow: /MobileRedirector
# Disallow: /MobileRegistration
# Disallow: /MobileRentalPropertyManager
# Disallow: /MobileRentals
# Disallow: /MobileReportLocation
# Disallow: /MobileReservation
# Disallow: /MobileRestaurantMenu
# Disallow: /MobileRestaurants
# Disallow: /MobileRestaurantSearch
# Disallow: /MobileReviewCollect
# Disallow: /MobileRoadTrip
# Disallow: /MobileS7Priority
# Disallow: /MobileSamsungRedirector
# Disallow: /MobileSamsungRegistration
# Disallow: /MobileSamsungStashToken
# Disallow: /MobileSamsungUpgradeAccount
# Disallow: /MobileSaves
# Disallow: /MobileSearch
# Disallow: /MobileShoppingCart
# Disallow: /MobileShoppingCoupon
# Disallow: /MobileShowForum
# Disallow: /MobileShowSpecialOffer
# Disallow: /MobileShowTopic
# Disallow: /MobileShowUserReviews
# Disallow: /MobileSiteIndex
# Disallow: /MobileSmartDeals
# Disallow: /MobileStreetView
# Disallow: /MobileTaggingAjax
# Disallow: /MobileTools
# Disallow: /MobileTourism
# Disallow: /MobileTravel
# Disallow: /MobileUberEstimateAjax
# Disallow: /MobileUpdateListing
# Disallow: /MobileUserReview
# Disallow: /MobileVacation_Packages
# Disallow: /MobileVacationRentalInquiry
# Disallow: /MobileVacationRentalReview
# Disallow: /MobileVacationRentals
# Disallow: /MobileVacationRentalSearch
# Disallow: /MobileVRACSearch
# Disallow: /MobileVRUserReview
# Disallow: /MobileWidgetEmbed
# Disallow: /MobileWinphoneLauncher
# Disallow: /ModuleAjax
# Disallow: /ModuleBootstrap
# Disallow: /MptUrl
# Disallow: /MsnForumFeedServlet
# Disallow: /MultiOwners
# Disallow: /MultiPartAjax
# Disallow: /MultiplusRegistration
# Disallow: /MyBookingsDetail
# Disallow: /MyBookingsVoucher
# Disallow: /MyInbox
# Disallow: /NetPromoterPopup
# Disallow: /NewMessage
# Disallow: /NewOwners
# Disallow: /NewsletterNews
# Disallow: /NewsLetterPlus
# Disallow: /NewsletterPopupBudgetRomanticFamilyPopup
# Disallow: /NewsletterPopupNewsletterPopup1
# Disallow: /NewsletterSendPassword
# Disallow: /NewsletterSignIn
# Disallow: /NewsletterSignOut
# Disallow: /NewsletterSignupWidget
# Disallow: /NewsPlus
# Disallow: /NewTopic
# Disallow: /nova
# Disallow: /OAuthRegistration
# Disallow: /OfferAnnouncementManagement
# Disallow: /OKPlusRegistration
# Disallow: /OpenGraphLander
# Disallow: /OpeningHours
# Disallow: /OverlayWidgetAjax
# Disallow: /OwnerActivityFeedAjax
# Disallow: /OwnerEmailManage
# Disallow: /OwnerHome
# Disallow: /OwnerNotificationSetting
# Disallow: /OwnerResponse
# Disallow: /Owners-
# Disallow: /OwnersDM
# Disallow: /OwnersTermsAndConditions
# Disallow: /OwnerSupport
# Disallow: /OwnerVerification
# Disallow: /OwnerVerifyLocation
# Disallow: /PageMoniker
# Disallow: /pages/rss_terms.html
# Disallow: /PageviewRecord
# Disallow: /PanoramaXml
# Disallow: /PasswordReset
# Disallow: /PaybackRegistration
# Disallow: /Payment
# Disallow: /PayNow
# Disallow: /pdfs/advertorials/
# Disallow: /pdfs/crm/
# Disallow: /pdfs/email/
# Disallow: /pdfs/tca/
# Disallow: /PersonalizedOnboarding
# Disallow: /PhoneTrackingOptOuts
# Disallow: /PhotoBox
# Disallow: /PhotoUpload
# Disallow: /Pin_Lander
# Disallow: /PoiRecommendationDashboard
# Disallow: /PoiRecommendationEditor
# Disallow: /PoiRecommendationList
# Disallow: /PoiTipDashboard
# Disallow: /PollController
# Disallow: /PostPhotos
# Disallow: /PostReply
# Disallow: /PostVideo
# Disallow: /Premium-
# Disallow: /PremiumAjax
# Disallow: /PremiumEdit
# Disallow: /PremiumPlans
# Disallow: /PreviewImage
# Disallow: /PrintGuide
# Disallow: /ProductCancellationLogApi
# Disallow: /ProductError
# Disallow: /ProfileGallery
# Disallow: /PromoTools
# Disallow: /PVLog
# Disallow: /QueryJson
# Disallow: /QuickReview
# Disallow: /RacDetail
# Disallow: /Rateit
# Disallow: /RateUserReview
# Disallow: /RatingAjax
# Disallow: /RatingPagingAjax
# Disallow: /RCPCrossSell
# Disallow: /Recaptcha
# Disallow: /recensioni
# Disallow: /Recent
# Disallow: /Redirect
# Disallow: /RegActivation
# Disallow: /Register
# Disallow: /RegistrationController
# Disallow: /RegistrationInterceptPopup
# Disallow: /RegistrationPage
# Disallow: /RemindMe
# Disallow: /RentalCarsRedirect
# Disallow: /RentalPropertyManager
# Disallow: /RentalsComparePartners
# Disallow: /RentalsSearch
# Disallow: /RentalsSupport
# Disallow: /RentalWatchSignup
# Disallow: /ReportIAP
# Disallow: /ReportPage
# Disallow: /ReportPost
# Disallow: /ReputationManagement
# Disallow: /ReputationManager
# Disallow: /ReservationAjax
# Disallow: /ResponsibleDisclosure
# Disallow: /RestaurantAdsManager
# Disallow: /RestaurantProductCart
# Disallow: /RestaurantSearch
# Disallow: /RestaurantSolutions
# Disallow: /RestaurantXSellAjax
# Disallow: /Resubscribe
# Disallow: /ReviewCollect
# Disallow: /ReviewExpress-
# Disallow: /ReviewExpressFAQ
# Disallow: /reviewit
# Disallow: /ReviewPerformance
# Disallow: /RexSpamFilterAjax
# Disallow: /RichContentEditor
# Disallow: /RMHome
# Disallow: /RMReviewCollection
# Disallow: /RoadTripMap
# Disallow: /Robots
# Disallow: /RSContentSharing
# Disallow: /RSManagementCenter
# Disallow: /RSOfflineBilling
# Disallow: /RsPartnerApi
# Disallow: /RT
# Disallow: /RuleBasedPopunder
# Disallow: /RuleBasedPopup
# Disallow: /S7PriorityRegistration
# Disallow: /SafetyManagementCenter
# Disallow: /SameGeoActivity
# Disallow: /SamsungRegistration
# Disallow: /SavedFlightsSearchesAjax
# Disallow: /SavedPhotos
# Disallow: /Saves
# Disallow: /screensaver/
# Disallow: /ScreensaverShade
# Disallow: /Search
# Disallow: /SelfServeAdvertising
# Disallow: /SendMessage
# Disallow: /SendToFriend
# Disallow: /SentConfirmationEmail
# Disallow: /SentryProxy
# Disallow: /ServiceWorker
# Disallow: /SetLangFilter
# Disallow: /SetReviewFilter
# Disallow: /Settings
# Disallow: /SetTranslationOption
# Disallow: /ShareWithFriends
# Disallow: /ShoppingCart
# Disallow: /ShoppingCoupon
# Disallow: /ShortlinkResolver
# Disallow: /ShortSurvey
# Disallow: /ShowSpecialOffer
# Disallow: /ShowTopicWindowShade
# Disallow: /ShowUrl
# Disallow: /ShowUserReviews_Cruises_Responsive
# Disallow: /ShowUserReviewsAirlines
# Disallow: /ShowUserReviewsAttractions
# Disallow: /ShowUserReviewsByRatings
# Disallow: /ShowUserReviewsCruises
# Disallow: /ShowUserReviewsGEO
# Disallow: /ShowUserReviewsHAC
# Disallow: /ShowUserReviewsHotels
# Disallow: /ShowUserReviewsRestaurants
# Disallow: /SingleClickOptOut
# Disallow: /SingleClickSignUp
# Disallow: /SingleUserReview
# Disallow: /SmartDealsHomeAjax
# Disallow: /SmsAjaxServlet
# Disallow: /SocialIapReporting
# Disallow: /SoftGatePopup
# Disallow: /SolutionsDisplay
# Disallow: /SortAttractions
# Disallow: /SortEateries
# Disallow: /SortHotels
# Disallow: /SortReviews
# Disallow: /SPCommerceInternal
# Disallow: /SpecialOfferManagement
# Disallow: /SpecialOfferWebview
# Disallow: /SponsoredListingAjax
# Disallow: /SponsoredListingCommerce
# Disallow: /SpotlightHome
# Disallow: /SPRedirect
# Disallow: /StartBooking
# Disallow: /static/decodeKey.txt
# Disallow: /StaticPage
# Disallow: /StaticVelocityPage
# Disallow: /StaticVelocityXmlPage
# Disallow: /StickerRequestAjax
# Disallow: /StruttaGameAjax
# Disallow: /SubscriptionLander
# Disallow: /SubscriptionPopup
# Disallow: /Summer06Widget
# Disallow: /summerbzz
# Disallow: /SurveyPanelPopup
# Disallow: /SyndicatedPhotos
# Disallow: /Tablet
# Disallow: /tacms
# Disallow: /TADemo
# Disallow: /TaggingAjax
# Disallow: /TagsJSONServlet
# Disallow: /TAMGFooterAjax
# Disallow: /TAMGSubLander
# Disallow: /TAMGSubOffers
# Disallow: /TAOffer
# Disallow: /TAScreenSaver
# Disallow: /TCDestinationsWidget
# Disallow: /TemporarilyClosedNoticeApi
# Disallow: /TestEmptyPage
# Disallow: /TestingTravelMaps
# Disallow: /TLMCountries
# Disallow: /TodaysLowestFaresAjax
# Disallow: /TourismManagementCenter
# Disallow: /trapdir
# Disallow: /TravelAdvice
# Disallow: /TravelerInterestNotificationEndpoint
# Disallow: /TravelersChoice?
# Disallow: /TravelersChoiceWidget
# Disallow: /TravellersChoice?
# Disallow: /TravelMap-
# Disallow: /TravelMap?
# Disallow: /TravelMapHome
# Disallow: /TripBarometer
# Disallow: /TripConnectAccommodations
# Disallow: /TripConnectBadge
# Disallow: /TripConnectPartner
# Disallow: /TripConnectPaymentForm
# Disallow: /TripConnectPlus
# Disallow: /TripConnectPremium
# Disallow: /Trips/
# Disallow: /TripsWebview
# Disallow: /TripWatchPromoAjax
# Disallow: /tucritica
# Disallow: /TwilioCallForward
# Disallow: /TwilioCallRouter
# Disallow: /TwilioConfirmPhoneNumber
# Disallow: /TypeAheadJson
# Disallow: /Unsubscribe
# Disallow: /UpdateCM
# Disallow: /UpdateContactsAjax
# Disallow: /UpdateListing
# Disallow: /UpdateSessionDatesAjax
# Disallow: /UploadMedia
# Disallow: /UserContent
# Disallow: /UserInteractionRecord
# Disallow: /UsernameValidation
# Disallow: /UserPage
# Disallow: /UserReview
# Disallow: /UserTrackingRecord
# Disallow: /VacationRentalIdeas
# Disallow: /VacationRentalInquiry
# Disallow: /VacationRentalReviewTab
# Disallow: /VacationRentalsAjax
# Disallow: /VacationRentalsBlog/?s
# Disallow: /VacationRentalSendToFriend
# Disallow: /VacationRentalsFAQ
# Disallow: /VacationRentalsPromoLander
# Disallow: /VacationRentalsTracking
# Disallow: /VacationRentalsXSiteAjax
# Disallow: /ValidateJson
# Disallow: /VerifyReview
# Disallow: /VideoController
# Disallow: /VideoGallery
# Disallow: /VideoHome?
# Disallow: /ViewAchAuthorization
# Disallow: /ViewAttachment
# Disallow: /ViewMandate
# Disallow: /VKRegistration
# Disallow: /VolunteerTranslations
# Disallow: /VRACSearch
# Disallow: /VRAffiliateClickoff
# Disallow: /VRDetailAjax
# Disallow: /VRInquirySent
# Disallow: /VRReviewManagement
# Disallow: /VRUserReview
# Disallow: /VSCookieRequest
# Disallow: /WatchTopic
# Disallow: /WatermarkPhoto
# Disallow: /WeatherAjax
# Disallow: /WeatherUnderground
# Disallow: /weimg
# Disallow: /WelboxCampaign
# Disallow: /WelboxRegistration
# Disallow: /WhatsNearby
# Disallow: /WidgetBrowserExtension
# Disallow: /WidgetEmbed
# Disallow: /Widgets-
# Disallow: /WidgetsAjax
# Disallow: /WifiPlus
# Disallow: /WindowsApp
# Disallow: /WriteReviewShade
# Disallow: /ZendeskRedirector
# Disallow: /ZendeskSSO
# Disallow: /ZipCodeLookupAjax
# Allow: /api/internal/*/location
# Allow: /api/partner_select/*/price_query
# Allow: /CheapFlightsHome
# Allow: /InfoCenter-a_ctr.april_en
# Allow: /js3/ta-mobile
# Allow: /js3/vr-shared
# Allow: /UserReview$
# Allow: /data/*/crosssellaccommodations

# %%
# robots.txt parser
# https://stackoverflow.com/questions/33596722/how-does-obey-robots-txt-using-python-2-7

from urllib import robotparser
from typing import Tuple


def can_access_site(base_url: str, access_path: str, agent_name: str="") -> Tuple[bool, int]:
    """
    This function will take in a base_url and an access_path (and optionally
    an agent_name and return whether the agent is allowed to access the specific
    path on the website. The function will return None in the first element of the
    tuple if a robots.txt is not found.

    agent name is the name of the robot. this can technically be set to anything
    but some websites have specific permissions for certain users (see the robots.txt
    for more detail)
    """
    parser = robotparser.RobotFileParser()
    parser.set_url(base_url  + '/robots.txt')

    try:
        parser.read()
    except Exception as e:
        # No robots.txt found
        return (None, None)

    return (parser.can_fetch(agent_name, access_path), parser.request_rate(agent_name))


print(can_access_site("https://www.tripadvisor.com", "/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html"))
print(can_access_site("https://www.facebook.com", "/"))
print(can_access_site("https://www.reddit.com", "/r/datascience"))
print(can_access_site("https://www.aida.acm.illinois.edu", "/"))
# Out:
# (True, None)
# (False, None)
# (True, None)
# (None, None)

# %% [markdown]
# ### Back to webscraping, we don't usually have the entire text data of an HTML page here right?
#
# #### Nope!
# BS4 itself doesn't support actually pulling text data from websites so you'll need another library to do that

# %%
# Here's the page for Golden Harbor on TripAdvisor 

golden_harbor_link = "https://www.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html"

# we're doing a GET request here (requests.post() also exists)
r = requests.get(golden_harbor_link)

soup = BeautifulSoup(r.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <link href="https://static.tacdn.com/favicon.ico?v2" id="favicon" rel="icon" type="image/x-icon"/>
#   <link color="#000000" href="https://static.tacdn.com/img2/brand_refresh/application_icons/mask-icon.svg" rel="mask-icon" sizes="any"/>
#   <meta content="#34e0a1" name="theme-color"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <script type="text/javascript">
#    window.taRollupsAreAsync = true;
#   </script>
#   <link crossorigin="" href="https://static.tacdn.com/css2/webfonts/TripSans/TripSans.css?v1.002" rel="stylesheet"/>
#   <title>
#    GOLDEN HARBOR, Champaign - Menu, Prices &amp; Restaurant Reviews - Tripadvisor
#   </title>
#   <meta content="TripAdvisor" property="al:ios:app_name"/>
#   <meta content="284876795" property="al:ios:app_store_id"/>
#   <meta content="284876795" name="twitter:app:id:ipad" property="twitter:app:id:ipad"/>
#   <meta content="284876795" name="twitter:app:id:iphone" property="twitter:app:id:iphone"/>
#   <meta content="tripadvisor://www.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html?m=33762" property="al:ios:url"/>
#   <meta content="tripadvisor://www.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html?m=33762" name="twitter:app:url:ipad" property="twitter:app:url:ipad"/>
#   <meta content="tripadvisor://www.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html?m=33762" name="twitter:app:url:iphone" property="twitter:app:url:iphone"/>
#   <meta content="Golden Harbor, Champaign, restaurant, reviews of restaurants, food, dining" name="keywords">
#    <meta content="Golden Harbor, Champaign: See 122 unbiased reviews of Golden Harbor, rated 4.5 of 5 on Tripadvisor and ranked #14 of 302 restaurants in Champaign." name="description">
#     <meta content="GOLDEN HARBOR, Champaign - Menu, Prices &amp; Restaurant Reviews - Tripadvisor" property="og:title">
#      <meta content="Golden Harbor, Champaign: See 122 unbiased reviews of Golden Harbor, rated 4.5 of 5 on Tripadvisor and ranked #14 of 302 restaurants in Champaign." property="og:description">
#       <meta content="https://media-cdn.tripadvisor.com/media/photo-s/0c/7f/fa/c7/fry-pork-belly-with-black.jpg" property="og:image">
#        <meta content="550" property="og:image:width">
#         <meta content="413" property="og:image:height">
#          <meta content="restaurant" property="og:type"/>
#          <meta content="http://www.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" property="og:url"/>
#          <meta content="Tripadvisor" property="og:site_name"/>
#          <meta content="100000982334629" property="fb:admins"/>
#          <meta content="162729813767876" property="fb:app_id"/>
#          <link href="/Restaurant_Review-g35790-d2010890-Reviews-or10-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" rel="next">
#           <meta content="https://static.tacdn.com/img2/brand_refresh/application_icons/post-image-550x550.png" name="twitter:image"/>
#           <meta content="5863091683" property="fb:pages"/>
#           <meta content="329182043776593" property="fb:pages"/>
#           <meta content="no-cache" http-equiv="pragma">
#            <meta content="no-cache,must-revalidate" http-equiv="cache-control">
#             <meta content="0" http-equiv="expires">
#              <meta content="width=device-width, initial-scale=1.0, user-scalable=no" name="viewport"/>
#              <link href="https://www.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en" rel="alternate"/>
#              <link href="https://www.tripadvisor.co.uk/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en-GB" rel="alternate"/>
#              <link href="https://www.tripadvisor.ca/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en-CA" rel="alternate"/>
#              <link href="https://fr.tripadvisor.ca/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="fr-CA" rel="alternate"/>
#              <link href="https://www.tripadvisor.it/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="it" rel="alternate"/>
#              <link href="https://www.tripadvisor.es/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="es" rel="alternate"/>
#              <link href="https://www.tripadvisor.de/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="de" rel="alternate"/>
#              <link href="https://www.tripadvisor.fr/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="fr" rel="alternate"/>
#              <link href="https://www.tripadvisor.jp/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="ja" rel="alternate"/>
#              <link href="https://cn.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="zh-Hans" rel="alternate"/>
#              <link href="https://www.tripadvisor.in/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en-IN" rel="alternate"/>
#              <link href="https://www.tripadvisor.se/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="sv" rel="alternate"/>
#              <link href="https://www.tripadvisor.nl/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="nl" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.br/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="pt" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.tr/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="tr" rel="alternate"/>
#              <link href="https://www.tripadvisor.dk/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="da" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.mx/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="es-MX" rel="alternate"/>
#              <link href="https://www.tripadvisor.ie/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en-IE" rel="alternate"/>
#              <link href="https://ar.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="ar" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.eg/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="ar-EG" rel="alternate"/>
#              <link href="https://www.tripadvisor.cz/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="cs" rel="alternate"/>
#              <link href="https://www.tripadvisor.at/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="de-AT" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.gr/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="el" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.au/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en-AU" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.my/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en-MY" rel="alternate"/>
#              <link href="https://www.tripadvisor.co.nz/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en-NZ" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.ph/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en-PH" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.sg/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en-SG" rel="alternate"/>
#              <link href="https://www.tripadvisor.co.za/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en-ZA" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.ar/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="es-AR" rel="alternate"/>
#              <link href="https://www.tripadvisor.cl/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="es-CL" rel="alternate"/>
#              <link href="https://www.tripadvisor.co/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="es-CO" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.pe/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="es-PE" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.ve/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="es-VE" rel="alternate"/>
#              <link href="https://www.tripadvisor.fi/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="fi" rel="alternate"/>
#              <link href="https://www.tripadvisor.co.hu/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="hu" rel="alternate"/>
#              <link href="https://www.tripadvisor.co.id/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="id" rel="alternate"/>
#              <link href="https://www.tripadvisor.co.il/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="he" rel="alternate"/>
#              <link href="https://www.tripadvisor.co.kr/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="ko" rel="alternate"/>
#              <link href="https://no.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="nb" rel="alternate"/>
#              <link href="https://pl.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="pl" rel="alternate"/>
#              <link href="https://www.tripadvisor.pt/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="pt-PT" rel="alternate"/>
#              <link href="https://www.tripadvisor.ru/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="ru" rel="alternate"/>
#              <link href="https://www.tripadvisor.sk/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="sk" rel="alternate"/>
#              <link href="https://www.tripadvisor.rs/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="sr" rel="alternate"/>
#              <link href="https://th.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="th" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.vn/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="vi" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.tw/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="zh-Hant" rel="alternate"/>
#              <link href="https://www.tripadvisor.ch/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="de-CH" rel="alternate"/>
#              <link href="https://fr.tripadvisor.ch/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="fr-CH" rel="alternate"/>
#              <link href="https://it.tripadvisor.ch/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="it-CH" rel="alternate"/>
#              <link href="https://en.tripadvisor.com.hk/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="en-HK" rel="alternate"/>
#              <link href="https://fr.tripadvisor.be/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="fr-BE" rel="alternate"/>
#              <link href="https://www.tripadvisor.be/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="nl-BE" rel="alternate"/>
#              <link href="https://www.tripadvisor.com.hk/Restaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" hreflang="zh-hk" rel="alternate"/>
#              <meta content="en" http-equiv="content-language"/>
#              <meta content="app-id=284876795" name="apple-itunes-app"/>
#              <script type="application/ld+json">
#               {"@context":"http:\u002F\u002Fschema.org","@type":"FoodEstablishment","name":"Golden Harbor","url":"\u002FRestaurant_Review-g35790-d2010890-Reviews-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html","image":"https:\u002F\u002Fmedia-cdn.tripadvisor.com\u002Fmedia\u002Fphoto-s\u002F0c\u002F7f\u002Ffa\u002Fc7\u002Ffry-pork-belly-with-black.jpg","priceRange":"$$ - $$$","aggregateRating":{"@type":"AggregateRating","ratingValue":"4.5","reviewCount":"122"},"address":{"@type":"PostalAddress","streetAddress":"505 S Neil St Suite 1","addressLocality":"Champaign","addressRegion":"Illinois","postalCode":"61820-5231","addressCountry":{"@type":"Country","name":"United States"}}}
#              </script>
#              <style data-rup="apg-Restaurant_Review-in" type="text/css">
#               .delineation,.delineation #btf_wrap,.delineation#MAIN{background-color:#f2f2f2}.delineation #btf_wrap{padding:0}@media (min-width:768px){.delineation #btf_wrap{padding:0 24px}}@media (max-width:1023px){.delineation #btf_wrap .ui_pagination{border-width:1px 0 0;border-style:solid;border-color:#e0e0e0}}.delineation #atf_meta{margin-bottom:12px}@media (max-width:767px){.delineation #atf_meta{padding-bottom:16px;border-width:0 0 1px;border-style:solid;border-color:#e0e0e0;background:#fff}}@media (min-width:1024px){.delineation{border-width:1px 0 0;border-style:solid;border-color:#e0e0e0}}.delineation #MAIN{margin:auto;border-top:none}.delineation #MAINWRAP.ui_container{padding:0}@media (min-width:1024px){.delineation #MAINWRAP.ui_container{padding:0 24px}}.delineation #BODYCON{padding-top:0;padding-right:0;overflow:visible}@media (max-width:1023px){.delineation #BODYCON{padding-left:0;padding-bottom:4px}}@media (max-width:1023px){.delineation.mwExtraPadding #BODYCON{padding-bottom:8px}}.delineation #LHR{border-right:0;padding:16px 12px 0 0;display:-webkit-flex;display:flex;-webkit-flex-direction:column;flex-direction:column}.ui_section:not(.no-bg){background-color:#fff}@media (min-width:1024px){.ui_section:not(.is-ad){padding:24px}}@media (min-width:1024px){.ui_section.custom_padding{padding:0 0 0 0}}@media (min-width:1024px){.ui_section{-moz-border-radius:2px;-webkit-border-radius:2px;border-radius:2px;border-width:1px;border-style:solid;border-color:#e0e0e0}}.ui_section.block_wrap{margin-bottom:12px;padding-top:16px}@media (min-width:768px){.ui_section.block_wrap{margin-bottom:24px}}.ui_section.block_wrap:not(#REVIEWS){padding-bottom:16px}@media (max-width:1023px){.ui_section.block_wrap,.ui_section.is-message,.ui_section.listItem{padding-left:16px;padding-right:16px;border-width:1px;border-style:solid;border-color:#e0e0e0}}@media (max-width:767px){.ui_section.block_wrap,.ui_section.is-message,.ui_section.listItem{border-width:1px 0;border-style:solid;border-color:#e0e0e0}}.ui_section.listItem{margin-top:4px;padding-top:4px;padding-bottom:0}@media (min-width:1024px){.ui_section.listItem{margin-top:8px}}@media (max-width:1023px){.mwExtraPadding .ui_section.listItem{margin-top:8px;padding-top:8px}}@media (max-width:767px){.ui_section.listItem.reducedWidth{margin-left:8px;margin-right:8px;padding-left:8px;padding-right:8px;border-width:0}}@media (max-width:767px){.ui_section.listItem[data-no-pt-mw=true]{padding-top:0}}.ui_section.listItem.boxShadow,.ui_section.listItem:hover{-webkit-box-shadow:0 0 8px 0 rgba(0,0,0,.25);-moz-box-shadow:0 0 8px 0 rgba(0,0,0,.25);box-shadow:0 0 8px 0 rgba(0,0,0,.25)}.ui_section.listItem.boxShadow:not(.small),.ui_section.listItem:hover:not(.small){border-bottom:1px solid #bababa}.ui_section.listFooter{margin-top:8px;padding:16px 24px}@media (max-width:1023px){.ui_section.listFooter{margin-top:4px;padding-left:16px;padding-right:16px;border-width:1px 0;border-style:solid;border-color:#e0e0e0}.mwExtraPadding .ui_section.listFooter{margin-top:8px}}.ui_section.is-ad{background:none;border:none}.ui_section.is-ad .gptAd.loaded{margin-top:4px}@media (min-width:1024px){.ui_section.is-ad .gptAd.loaded{margin-top:8px}}@media (max-width:1023px){.mwExtraPadding .ui_section.is-ad .gptAd.loaded{margin-top:8px}}.ui_section.no-bg{background:none;border:none}.ui_section.listAlert{margin-top:8px}@media (max-width:767px){.MobileRestaurant_Review .delineation #atf_meta,.Restaurant_Review .delineation #atf_meta{padding-bottom:0}}
# @font-face{font-weight:400;font-style:normal;font-family:TripAdvisor_Regular;src:url(data:font/woff;base64,...)}
# .ui_icon:before{display:inline-block;font-style:normal;font-weight:400;font-variant:normal;font-size:inherit;line-height:1;font-family:TripAdvisor_Regular!important;-ms-transform:rotate(-.001deg);-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;speak:none;text-decoration:underline}.ui_icon.ui_icon:before{text-decoration:none}.rtl .ui_icon:after,.rtl .ui_icon:before{-webkit-transform:scaleX(-1);-moz-transform:scaleX(-1);-ms-transform:scaleX(-1);-ms-filter:"progid:DXImageTransform.Microsoft.BasicImage(rotation=0, mirror=1)";transform:scaleX(-1)}
# .ui_icon.accessible:before{content:"\e0fc"}.ui_icon.activities:before{content:"\e063"}.ui_icon.add-friend-fill:before,.ui_icon.add-friend:before{content:"\e087"}.ui_icon.adult:before{content:"\e06e"}.ui_icon.air-conditioning:before{content:"\e0e9"}.ui_icon.alcohol:before{content:"\e104"}.ui_icon.alert-fill:before{content:"\e095"}.ui_icon.alert:before{content:"\e096"}.ui_icon.ambience:before{content:"\e105"}.ui_icon.amusement-parks-fill:before{content:"\e13c"}.ui_icon.amusement-parks:before{content:"\e05b"}.ui_icon.announcement-fill-26deg:before{content:"\e071"}.ui_icon.announcement-fill:before{content:"\e072"}.ui_icon.archive:before{content:"\e07e"}.ui_icon.arrow-down-thick:before{content:"\e07d"}.ui_icon.arrow-down:before{content:"\e07c"}.ui_icon.arrow-left-prohibited:before{content:"\e061"}.ui_icon.arrow-left-thick:before{content:"\e080"}.ui_icon.arrow-left:before{content:"\e07f"}.ui_icon.arrow-right-thick:before{content:"\e07a"}.ui_icon.arrow-right:before{content:"\e079"}.ui_icon.arrow-up-thick:before{content:"\e077"}.ui_icon.arrow-up:before{content:"\e076"}.ui_icon.attractions-fill:before{content:"\e14a"}.ui_icon.attractions:before{content:"\e002"}.ui_icon.audio:before{content:"\e0ee"}.ui_icon.award:before{content:"\e0a0"}.ui_icon.bag:before{content:"\e0f3"}.ui_icon.bakery-fill:before{content:"\e13d"}.ui_icon.bakery:before{content:"\e125"}.ui_icon.bar-fill:before{content:"\e13e"}.ui_icon.bar:before{content:"\e068"}.ui_icon.bathroom-fill:before{content:"\e0cb"}.ui_icon.bell:before{content:"\e0a1"}.ui_icon.beverage:before{content:"\e0ef"}.ui_icon.bookmark-fill:before{content:"\e0bb"}.ui_icon.bookmark:before{content:"\e0ba"}.ui_icon.bubble-rating-bg:before{content:"\e00a"}.ui_icon.bubble-rating-empty:before{content:"\e00d"}.ui_icon.bubble-rating-full:before{content:"\e00b"}.ui_icon.bubble-rating-half:before{content:"\e00c"}.ui_icon.buffet:before{content:"\e106"}.ui_icon.calendar:before{content:"\e015"}.ui_icon.camera-fill:before{content:"\e0a4"}.ui_icon.camera:before{content:"\e010"}.ui_icon.caret-down:before{content:"\e04a"}.ui_icon.caret-left:before{content:"\e04d"}.ui_icon.caret-right:before{content:"\e047"}.ui_icon.caret-up:before{content:"\e044"}.ui_icon.casino-fill:before{content:"\e13f"}.ui_icon.casino:before{content:"\e0dd"}.ui_icon.castle:before{content:"\e0de"}.ui_icon.certificate-of-excellence:before{content:"\e059"}.ui_icon.checkbox-border:before{content:"\e093"}.rtl .ui_icon.checkbox-checked:after,.rtl .ui_icon.checkbox-checked:before{-webkit-transform:scale(1);transform:scale(1)}.ui_icon.checkbox-checked:before{content:"\e094"}.rtl .ui_icon.checkmark-boxed:after,.rtl .ui_icon.checkmark-boxed:before{-webkit-transform:scale(1);transform:scale(1)}.ui_icon.checkmark-boxed:before{content:"\e02a"}.rtl .ui_icon.checkmark-circle-fill:after,.rtl .ui_icon.checkmark-circle-fill:before{-webkit-transform:scale(1);transform:scale(1)}.ui_icon.checkmark-circle-fill:before{content:"\e08c"}.rtl .ui_icon.checkmark:after,.rtl .ui_icon.checkmark:before{-webkit-transform:scale(1);transform:scale(1)}.ui_icon.checkmark:before{content:"\e02b"}.ui_icon.child:before{content:"\e06f"}.ui_icon.children:before{content:"\e08a"}.ui_icon.classes-workshops-fill:before{content:"\e14d"}.ui_icon.classes-workshops:before{content:"\e0fe"}.ui_icon.clock:before{content:"\e016"}.ui_icon.coffee-tea-cafe-fill:before{content:"\e140"}.ui_icon.coffee-tea-cafe:before{content:"\e05e"}.ui_icon.comments-fill:before{content:"\e06c"}.ui_icon.comments:before{content:"\e06b"}.ui_icon.compass-fill:before{content:"\e0c8"}.ui_icon.compass:before{content:"\e0c7"}.ui_icon.conference-center:before{content:"\e0ed"}.ui_icon.credit-card:before{content:"\e0ac"}.ui_icon.cruises:before{content:"\e007"}.ui_icon.custom-note:before{content:"\e09d"}.ui_icon.deals:before{content:"\e0a2"}.ui_icon.delivery:before{content:"\e107"}.ui_icon.dessert-fill:before{content:"\e141"}.ui_icon.dessert:before{content:"\e126"}.ui_icon.destination:before{content:"\e0a3"}.ui_icon.diagonal-circle-half- ...
# .ui_icon_stacked{position:relative;display:inline-block;width:24px;height:24px;font-size:24px;line-height:1;vertical-align:middle}.ui_icon_stacked .ui_icon.stacked{position:absolute;top:0;left:0;line-height:0}
# blockquote,dd,div,dl,dt,fieldset,form,h1,h2,h3,h4,h5,h6,input,legend,li,ol,p,pre,td,textarea,th,ul{margin:0;padding:0}table{border-collapse:collapse;border-spacing:0}abbr,fieldset,img{border:0}address,caption,cite,code,dfn,var{font-style:normal;font-weight:400}ol,ul{list-style:none}caption,th{text-align:left}h1,h2,h3,h4,h5,h6{font-size:100%;font-weight:700}q:after,q:before{content:""}p{margin-bottom:12px}body{margin:0;margin-right:constant(safe-area-inset-right);margin-right:env(safe-area-inset-right);margin-left:constant(safe-area-inset-left);margin-left:env(safe-area-inset-left);padding:0;font-size:medium;font-family:Arial,Tahoma,Bitstream Vera Sans,sans-serif;color:#2c2c2c;background-color:#fff;-webkit-font-smoothing:antialiased}legend{margin-left:-8px !ie}input[type=checkbox],input[type=radio]{cursor:pointer}input[disabled=disabled]{cursor:auto}button,input,select,textarea{font-family:inherit}.br{line-height:14px}.wrap{height:100%;overflow:hidden}.easyClear{zoom:1}.easyClear:after{display:block;height:0;line-height:0;clear:both;content:".";visibility:hidden;zoom:1}.hidden{display:none}.bidiEmbed{unicode-bidi:embed}
# body{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;margin-right:constant(safe-area-inset-right);margin-right:env(safe-area-inset-right);margin-left:constant(safe-area-inset-left);margin-left:env(safe-area-inset-left)}body .has-modal-open{overflow:hidden}body .background_delineation{background-color:#f2f2f2}a{text-decoration:none}
# .ui_button_group{position:relative;zoom:1 !ie}.ui_button_group:after{display:block;height:0;visibility:hidden;content:"";clear:both}.ui_button_group .ui_button{margin-right:12px;float:left}.ui_button_group .ui_button:last-child{margin-right:0}.ui_button{-webkit-appearance:none;-moz-appearance:none;appearance:none;position:relative;display:inline-block;padding:8px 16px;font-weight:700;font-family:inherit;border:1px solid transparent;border-radius:2px;background-clip:padding-box;box-sizing:border-box;font-size:14px;line-height:18px;text-align:center;text-decoration:none;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;cursor:pointer;transition:background-color .2s}.ui_button:focus:active{text-decoration:none;outline:none}.ui_button.hidden{display:none}.ui_button.truncate{overflow:hidden;text-overflow:ellipsis;white-space:nowrap}.ui_button.small{padding:6px 10px;font-size:12px;line-height:16px}.ui_button.small .ui_loader>span{width:7px;height:6px}.ui_button.small .ui_loader>span:before{width:6px;height:6px;border-radius:6px}.ui_button.large{padding:10px 22px;font-size:16px;line-height:20px}.ui_button.large .ui_loader>span{width:13px;height:10px}.ui_button.large .ui_loader>span:before{width:10px;height:10px;border-radius:10px}.ui_button.resize{font-size:10px}.ui_button.fullwidth{width:100%}.ui_button.danger{border-color:#e0e0e0 #b7b7b7 #b7b7b7 #e0e0e0;background-color:#fff;box-shadow:1px 1px 0 0 rgba(0,0,0,.05);color:#c00}.ui_button .ui_loader{display:none;position:absolute;top:0;left:0;bottom:0;right:0;-webkit-justify-content:center;justify-content:center;-webkit-align-content:center;align-content:center}.ui_button.loading{color:transparent!important;pointer-events:none}.ui_button.loading .ui_loader{display:-webkit-flex;display:flex}.ui_button.secondary .ui_loader>span:before,.ui_button.standard .ui_loader>span:before{-webkit-animation-name:pulseDotLight;animation-name:pulseDotLight}.ui_button.original .ui_loader>span:before,.ui_button.primary .ui_loader>span:before{background-color:#fff;-webkit-animation-name:pulseDotDark;animation-name:pulseDotDark}.styleguide .ui_button{font-weight:700}.styleguide .ui_button.disabled{pointer-events:none}
# .ui_button.original{border-radius:12px;border-color:#f2b203;background-color:#f2b203;color:#000}.ui_button.original.chevron:after{border-color:#000}.ui_button.original.disabled{opacity:.32;border-color:transparent;cursor:auto}.offer:hover .ui_button.original:not(.disabled),.ui_button.original:not(.disabled):hover,.ui_button_activator:hover .ui_button.original:not(.disabled){text-decoration:none;border-color:#fee190;background-color:#fee190}.offer:focus .ui_button.original:not(.disabled),.ui_button.original:not(.disabled):focus,.ui_button_activator:focus .ui_button.original:not(.disabled){outline:none;text-decoration:none;box-shadow:0 0 0 2px #fff,0 0 0 3px #000}.offer:active .ui_button.original:not(.disabled),.ui_button.original:not(.disabled):active,.ui_button_activator:active .ui_button.original:not(.disabled){background-color:#fcc42b;border-color:#fcc42b}
# .ui_button.primary{border-color:#004f32;border-radius:3px;background-color:#004f32;color:#fff}.ui_button.primary.chevron:after{border-color:#fff}.ui_button.primary.disabled{opacity:.35;border-color:transparent;cursor:auto}.offer:hover .ui_button.primary:not(.disabled),.ui_button.primary:not(.disabled):hover,.ui_button_activator:hover .ui_button.primary:not(.disabled){text-decoration:none;border-color:#00aa6c;background-color:#00aa6c}.offer:active .ui_button.primary:not(.disabled),.ui_button.primary:not(.disabled):active,.ui_button_activator:active .ui_button.primary:not(.disabled){background-color:#00aa6c;border-color:#00aa6c}.cx_brand_refresh_phase2 .ui_button.primary{background-color:#000;border-color:#000}.cx_brand_refresh_phase2 .ui_button.primary.disabled{opacity:.32}.cx_brand_refresh_phase2 .ui_button.primary:not(.disabled):hover,.offer:hover .cx_brand_refresh_phase2 .ui_button.primary:not(.disabled),.ui_button_activator:hover .cx_brand_refresh_phase2 .ui_button.primary:not(.disabled){border-color:#292929;background-color:#292929}.cx_brand_refresh_phase2 .ui_button.primary:not(.disabled):focus,.offer:focus .cx_brand_refresh_phase2 .ui_button.primary:not(.disabled),.ui_button_activator:focus .cx_brand_refresh_phase2 .ui_button.primary:not(.disabled){outline:none;text-decoration:none;box-shadow:0 0 0 2px #fff,0 0 0 3px #000}.cx_brand_refresh_phase2 .ui_button.primary:not(.disabled):active,.offer:active .cx_brand_refresh_phase2 .ui_button.primary:not(.disabled),.ui_button_activator:active .cx_brand_refresh_phase2 .ui_button.primary:not(.disabled){border-color:#525252;background-color:#525252;box-shadow:none}
# .ui_button.standard{border-color:#e6e6e6 #ccc #ccc #e6e6e6;background-color:#f0f0f0;color:#4a4a4a}.rtl .ui_button.standard{border-color:#e6e6e6 #e6e6e6 #ccc #ccc}.ui_button.standard.chevron:after{border-color:#4a4a4a}.ui_button.standard.disabled{opacity:.35;border-color:transparent;cursor:auto}.offer:hover .ui_button.standard:not(.disabled),.ui_button.standard:not(.disabled):hover,.ui_button_activator:hover .ui_button.standard:not(.disabled){text-decoration:none;background-color:#e6e6e6}.offer:active .ui_button.standard:not(.disabled),.ui_button.standard:not(.disabled):active,.ui_button_activator:active .ui_button.standard:not(.disabled){background-color:#dfdfdf;border-color:#dfdfdf}
# .ui_button.secondary{border-color:#004f32;border-radius:3px;background-color:#fff;color:#004f32}.ui_button.secondary.chevron:after{border-color:#004f32}.ui_button.secondary.disabled{opacity:.35;border-color:#8c8c8c;cursor:auto}.offer:hover .ui_button.secondary:not(.disabled),.ui_button.secondary:not(.disabled):hover,.ui_button_activator:hover .ui_button.secondary:not(.disabled){text-decoration:none;border-color:#00aa6c;color:#00aa6c}.offer:active .ui_button.secondary:not(.disabled),.ui_button.secondary:not(.disabled):active,.ui_button_activator:active .ui_button.secondary:not(.disabled){border-color:#00aa6c;color:#00aa6c}.offer:active .ui_button.secondary:not(.disabled).chevron:after,.ui_button.secondary:not(.disabled):active.chevron:after,.ui_button_activator:active .ui_button.secondary:not(.disabled).chevron:after{border-color:#00aa6c}.cx_brand_refresh_phase2 .ui_button.secondary{border-color:#000;color:#000}.cx_brand_refresh_phase2 .ui_button.secondary.disabled{opacity:.32}.cx_brand_refresh_phase2 .ui_button.secondary:not(.disabled):hover,.offer:hover .cx_brand_refresh_phase2 .ui_button.secondary:not(.disabled),.ui_button_activator:hover .cx_brand_refresh_phase2 .ui_button.secondary:not(.disabled){background-color:#d6d6d6;border-color:#000;color:#000}.cx_brand_refresh_phase2 .ui_button.secondary:not(.disabled):focus,.offer:focus .cx_brand_refresh_phase2 .ui_button.secondary:not(.disabled),.ui_button_activator:focus .cx_brand_refresh_phase2 .ui_button.secondary:not(.disabled){outline:none;text-decoration:none;box-shadow:0 0 0 2px #fff,0 0 0 3px #000}.cx_brand_refresh_phase2 .ui_button.secondary:not(.disabled):active,.offer:active .cx_brand_refresh_phase2 .ui_button.secondary:not(.disabled),.ui_button_activator:active .cx_brand_refresh_phase2 .ui_button.secondary:not(.disabled){background-color:#adadad;border-color:#000;color:#000;box-shadow:none}
# .ui_button.icon_to_text{border-color:#e0e0e0;background-color:#fff;color:#000}.ui_button.icon_to_text .cta{display:none}@media (min-width:768px){.ui_button.icon_to_text .cta{display:inline-block;margin-right:4px}}.ui_button.icon_to_text .ui_icon{font-size:20px;line-height:24px}@media (min-width:768px){.ui_button.icon_to_text .ui_icon{font-size:18px;line-height:22px}}.ui_button.icon_to_text .count{display:inline-block;position:relative;top:-3px;margin:-3px 0 -3px 4px;padding:2px 4px 2px 2px;border-color:#000;border-radius:2px;background-color:#000;font-weight:400;font-size:10px;line-height:14px;color:#fff}@media (min-width:768px){.ui_button.icon_to_text .count{top:-2px;margin-top:-2px;margin-bottom:-2px}}.ui_button.icon_to_text .count:before{position:absolute;top:50%;right:100%;width:0;height:0;margin-top:-4px;border:4px solid transparent;border-right-color:inherit;content:""}@media (min-width:768px){.ui_button.icon_to_text:hover{background-color:#e0e0e0}}.ui_button.disabled{opacity:.35;cursor:auto}
# .ui_button.chevron:not(.lte_ie8){padding-right:36px}.ui_button.chevron:not(.lte_ie8):after{position:absolute;top:50%;right:13px;width:6px;height:6px;margin-top:-4px;border-width:0 2px 2px 0;border-style:solid;content:"";-ms-transform:rotate(-45deg);-webkit-transform:rotate(-45deg);transform:rotate(-45deg)}.ui_button.chevron.small:not(.lte_ie8){padding-right:30px}.ui_button.chevron.small:not(.lte_ie8):after{width:5px;height:5px}.ui_button.chevron.large:not(.lte_ie8){padding-right:42px}.ui_button.chevron.large:not(.lte_ie8):after{width:7px;height:7px}.rtl .ui_button.chevron:not(.lte_ie8):after{-ms-transform:rotate(45deg);-webkit-transform:rotate(45deg);transform:rotate(45deg)}.styleguide .ui_button.chevron:after{width:8px;height:8px}.styleguide .ui_button.chevron:after.small{width:7px;height:7px}.styleguide .ui_button.chevron:after.large{width:9px;height:9px}
# .ui_bubble_rating{display:inline-block;position:relative}.ui_bubble_rating:after,.ui_bubble_rating:before{display:inline-block;font-style:normal;font-weight:400;font-variant:normal;font-size:inherit;line-height:1;font-family:TripAdvisor_Regular!important;-ms-transform:rotate(-.001deg);-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;speak:none}.ui_bubble_rating:before{color:#fff;display:block;content:"\e00a\e00a\e00a\e00a\e00a"}.ui_bubble_rating:after{position:absolute;top:0;left:0;color:#00aa6c}.ui_bubble_rating.bubble_00:after,.ui_bubble_rating.bubble_0:after{content:"\e00d\e00d\e00d\e00d\e00d"}.ui_bubble_rating.bubble_05:after{content:"\e00c\e00d\e00d\e00d\e00d"}.ui_bubble_rating.bubble_1:after,.ui_bubble_rating.bubble_10:after{content:"\e00b\e00d\e00d\e00d\e00d"}.ui_bubble_rating.bubble_15:after{content:"\e00b\e00c\e00d\e00d\e00d"}.ui_bubble_rating.bubble_2:after,.ui_bubble_rating.bubble_20:after{content:"\e00b\e00b\e00d\e00d\e00d"}.ui_bubble_rating.bubble_25:after{content:"\e00b\e00b\e00c\e00d\e00d"}.ui_bubble_rating.bubble_3:after,.ui_bubble_rating.bubble_30:after{content:"\e00b\e00b\e00b\e00d\e00d"}.ui_bubble_rating.bubble_35:after{content:"\e00b\e00b\e00b\e00c\e00d"}.ui_bubble_rating.bubble_4:after,.ui_bubble_rating.bubble_40:after{content:"\e00b\e00b\e00b\e00b\e00d"}.ui_bubble_rating.bubble_45:after{content:"\e00b\e00b\e00b\e00b\e00c"}.ui_bubble_rating.bubble_5:after,.ui_bubble_rating.bubble_50:after{content:"\e00b\e00b\e00b\e00b\e00b"}.rtl .ui_bubble_rating:after,.rtl .ui_bubble_rating:before{-webkit-transform:scaleX(-1);-moz-transform:scaleX(-1);-ms-transform:scaleX(-1);-ms-filter:"progid:DXImageTransform.Microsoft.BasicImage(rotation=0, mirror=1)";transform:scaleX(-1)}@media print{.ui_bubble_rating:before{color:transparent}}
# .ui_single_bubble_rating{display:inline-block;position:relative}.ui_single_bubble_rating:after,.ui_single_bubble_rating:before{display:inline-block;font-style:normal;font-weight:400;font-variant:normal;font-size:inherit;line-height:1;font-family:TripAdvisor_Regular!important;-ms-transform:rotate(-.001deg);-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;speak:none}.ui_single_bubble_rating:before{content:"\e00a";color:#fff;display:block}.ui_single_bubble_rating:after{content:"\e00b";position:absolute;top:0;left:0;color:#00aa6c}
# .ui_star_rating{display:inline-block;position:relative}.ui_star_rating:after,.ui_star_rating:before{display:inline-block;font-style:normal;font-weight:400;font-variant:normal;font-size:inherit;line-height:1;font-family:TripAdvisor_Regular!important;-ms-transform:rotate(-.001deg);-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;speak:none}.ui_star_rating:before{content:"\e088\e088\e088\e088\e088";color:#c4c4c4;display:block}.ui_star_rating:after{position:absolute;top:0;left:0;color:#636363}.ui_star_rating.star_05:after{content:"\e089"}.ui_star_rating.star_1:after,.ui_star_rating.star_10:after{content:"\e088"}.ui_star_rating.star_15:after{content:"\e088\e089"}.ui_star_rating.star_2:after,.ui_star_rating.star_20:after{content:"\e088\e088"}.ui_star_rating.star_25:after{content:"\e088\e088\e089"}.ui_star_rating.star_3:after,.ui_star_rating.star_30:after{content:"\e088\e088\e088"}.ui_star_rating.star_35:after{content:"\e088\e088\e088\e089"}.ui_star_rating.star_4:after,.ui_star_rating.star_40:after{content:"\e088\e088\e088\e088"}.ui_star_rating.star_45:after{content:"\e088\e088\e088\e088\e089"}.ui_star_rating.star_5:after,.ui_star_rating.star_50:after{content:"\e088\e088\e088\e088\e088"}.ui_star_rating.no_bg:before{content:""}.ui_star_rating.no_bg:after{position:static}.rtl .ui_star_rating:after,.rtl .ui_star_rating:before{-webkit-transform:scaleX(-1);-moz-transform:scaleX(-1);-ms-transform:scaleX(-1);-ms-filter:"progid:DXImageTransform.Microsoft.BasicImage(rotation=0, mirror=1)";transform:scaleX(-1)}
# .ui_form{background-color:#fff}.ui_form.alternate{background-color:#e9e8e2}.ui_form .legend{margin:0;padding:0}.ui_form .fieldset{margin:0;padding:24px;border:none}.ui_form .transition,.ui_form .transition:after,.ui_form .transition:before{-webkit-transition:all .3s ease-in-out;-moz-transition:all .3s ease-in-out;-ms-transition:all .3s ease-in-out;-o-transition:all .3s ease-in-out;transition:all .3s ease-in-out}.ui_input_text.primary,.ui_select.primary,.ui_textarea.primary{border:1px solid #00aa6c}.ui_input_text.error,.ui_select.error,.ui_textarea.error{border:1px solid #ff3860}.ui_input_text.disabled,.ui_select.disabled,.ui_textarea.disabled{box-shadow:none;pointer-events:none;opacity:.5}
# .ui_fieldset.x2{box-sizing:border-box}.ui_fieldset.x2 .fieldset_item{width:49%;margin-right:2%;box-sizing:border-box;float:left}.ui_fieldset.x2 .fieldset_item:last-child{margin-right:0}
# .ui_label_group{display:block;margin-bottom:12px}.ui_label_group .label{display:block;margin-bottom:4px;font-weight:700;font-size:12px;line-height:14px}.ui_label_group .required{color:#d80007;line-height:1;vertical-align:text-top}.ui_label_group .label+.exclamation-circle{display:none}.ui_label_group.inline .label{display:inline;padding-left:24px;font-weight:400;cursor:pointer}
# .ui_input_group [class^=ui_input]{margin-bottom:12px}
# .ui_checkbox .label,.ui_checkbox label,.ui_input_checkbox .label,.ui_input_checkbox label{position:relative;cursor:pointer;display:inline-block}.ui_checkbox .label:before,.ui_checkbox label:before,.ui_input_checkbox .label:before,.ui_input_checkbox label:before{position:absolute;top:0;left:0;width:1em;height:1em;background-color:#fff;border:1px solid #8c8c8c;border-radius:2px;box-shadow:inset 0 0 2px rgba(0,0,0,.1);font:normal 700 normal 1em/1 TripAdvisor_Regular;color:#fff;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;content:""}.ui_checkbox .input_hidden,.ui_checkbox input,.ui_input_checkbox .input_hidden,.ui_input_checkbox input{display:none}.ui_checkbox .input_hidden:checked+.label:before,.ui_checkbox .input_hidden:checked+label:before,.ui_checkbox input:checked+.label:before,.ui_checkbox input:checked+label:before,.ui_input_checkbox .input_hidden:checked+.label:before,.ui_input_checkbox .input_hidden:checked+label:before,.ui_input_checkbox input:checked+.label:before,.ui_input_checkbox input:checked+label:before{background-color:#004f32;content:"\e02b";speak:none}.ui_checkbox{display:inline-block}.ui_checkbox .label,.ui_checkbox label{padding-left:24px;box-sizing:content-box}.ui_checkbox+.ui_checkbox{margin-left:1rem}.cx_brand_refresh_phase2 .ui_checkbox .label:before,.cx_brand_refresh_phase2 .ui_checkbox label:before,.cx_brand_refresh_phase2 .ui_input_checkbox .label:before,.cx_brand_refresh_phase2 .ui_input_checkbox label:before{border-color:#000}.cx_brand_refresh_phase2 .ui_checkbox .input_hidden:checked+.label:before,.cx_brand_refresh_phase2 .ui_checkbox .input_hidden:checked+label:before,.cx_brand_refresh_phase2 .ui_checkbox input:checked+.label:before,.cx_brand_refresh_phase2 .ui_checkbox input:checked+label:before,.cx_brand_refresh_phase2 .ui_input_checkbox .input_hidden:checked+.label:before,.cx_brand_refresh_phase2 .ui_input_checkbox .input_hidden:checked+label:before,.cx_brand_refresh_phase2 .ui_input_checkbox input:checked+.label:before,.cx_brand_refresh_phase2 .ui_input_checkbox input:checked+label:before{background-color:#000}
# .ui_input_radio .label,.ui_input_radio label,.ui_radio .label,.ui_radio label{position:relative}.ui_input_radio .label:before,.ui_input_radio label:before,.ui_radio .label:before,.ui_radio label:before{position:absolute;top:-1px;left:1px;width:15px;height:15px;background-color:#fff;border:1px solid #8c8c8c;border-radius:100%;box-shadow:inset 0 0 2px rgba(0,0,0,.1);font:normal normal normal 1em/1 TripAdvisor_Regular;font-size:11px;line-height:15px;text-indent:2px;color:#fff;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;content:""}.ui_input_radio .input_hidden,.ui_input_radio input,.ui_radio .input_hidden,.ui_radio input{display:none}.ui_input_radio .input_hidden:checked+.label:before,.ui_input_radio .input_hidden:checked+label:before,.ui_input_radio input:checked+.label:before,.ui_input_radio input:checked+label:before,.ui_radio .input_hidden:checked+.label:before,.ui_radio .input_hidden:checked+label:before,.ui_radio input:checked+.label:before,.ui_radio input:checked+label:before{color:#004f32;content:"\e00a";speak:none;font-size:12px}.ui_radio{display:inline-block}.ui_radio .label,.ui_radio label{padding-left:24px;box-sizing:content-box}.ui_radio .label.checked:before,.ui_radio label.checked:before{color:#004f32;content:"\e00a";speak:none;font-size:12px}.ui_radio+.ui_radio{margin-left:1rem}
# .ui_input_text{width:100%;padding:6px 12px;border:1px solid #f2f2f2;border-radius:2px;background-color:#fff;box-sizing:border-box;font-size:14px;font-family:inherit}.ui_input_text,.ui_input_text:focus{box-shadow:inset 0 2px 1px rgba(0,0,0,.1)}.ui_input_text:focus{border-color:#00aa6c;outline:none}.ui_input_text::-webkit-input-placeholder{color:#8c8c8c}.ui_input_text::placeholder{color:#8c8c8c}.mark_as_error .ui_input_text{border-color:#c00;box-shadow:inset 0 2px 1px rgba(0,0,0,.1)}
# .ui_textarea{width:100%;padding:6px 12px;border:1px solid #e0e0e0;border-radius:3px;background-color:#fff;box-sizing:border-box;font-size:14px;font-family:inherit;resize:vertical}.ui_textarea,.ui_textarea:focus{box-shadow:inset 0 2px 1px rgba(0,0,0,.1)}.ui_textarea:focus{border-color:#00aa6c;outline:none}.mark_as_error .ui_textarea{border-color:#c00;box-shadow:inset 0 2px 1px rgba(0,0,0,.1)}.styleguide .ui_textarea{padding:6px 12px}
# .ui_select{position:relative}.ui_select .options{display:none}.ui_select .closed_text,.ui_select .select-label{position:relative;display:inline-block;font-weight:700;border:1px solid;border-color:#e6e6e6 #ccc #ccc #e6e6e6;border-radius:3px;background-clip:padding-box;box-sizing:border-box;text-decoration:none;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;cursor:pointer;background-color:#f0f0f0;box-shadow:1px 1px 0 0 rgba(0,0,0,.07);color:#4a4a4a;padding:5px 30px 7px 10px;font-size:14px;line-height:16px;white-space:nowrap;overflow:hidden;text-overflow:ellipsis}.ui_select .closed_text:hover,.ui_select .select-label:hover{background-color:#e6e6e6}.ui_select .closed_text:active,.ui_select .select-label:active{background-color:#dfdfdf;border-color:#dfdfdf;box-shadow:none}.ui_select .closed_text:after,.ui_select .select-label:after{position:absolute;right:10px;margin-left:12px;font-family:TripAdvisor_Regular;font-size:18px;line-height:1;color:#999;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;content:"\e03e";speak:none}.mark_as_error .closed_text,.mark_as_error .select-label{border-color:#d80007}.styleguide .ui_select{display:inline-block}.styleguide .ui_select+.ui_select{margin-left:1rem}
# .mark_as_error{position:relative}.mark_as_error .label{color:#d80007}.mark_as_error .label+.exclamation-circle{display:block}.mark_as_error .label+.exclamation-circle:before{position:absolute;top:30px;right:12px;font-size:24px;color:#d80007}
# ...
# require(['ta/p13n/placements','ta/page','$prp/global_nav_dropdowns/handlers'], function(placements, impl) {
# window.ta.plc_global_nav_dropdowns_0_handlers = placements.load('global_nav_dropdowns','handlers.js', { 'name': 'global_nav_dropdowns', 'occurrence': 0, 'id': 'taplc_global_nav_dropdowns_0', 'location_id': 2010890, 'servletClass': 'com.TripResearch.servlet.eatery.responsive.RestaurantReviewServlet', 'servletName': 'Restaurant_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/global_nav_action_inbox/handlers'], function(placements, impl) {
# window.ta.plc_global_nav_action_inbox_empty_0_handlers = placements.load('global_nav_action_inbox','handlers.js', { 'name': 'global_nav_action_inbox:empty', 'occurrence': 0, 'id': 'taplc_global_nav_action_inbox_empty_0', 'location_id': 2010890, 'servletClass': 'com.TripResearch.servlet.eatery.responsive.RestaurantReviewServlet', 'servletName': 'Restaurant_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/masthead_search/handlers'], function(placements, impl) {
# window.ta.plc_masthead_search_empty_0_handlers = placements.load('masthead_search','handlers.js', { 'name': 'masthead_search:empty', 'occurrence': 0, 'id': 'taplc_masthead_search_empty_0', 'location_id': 2010890, 'servletClass': 'com.TripResearch.servlet.eatery.responsive.RestaurantReviewServlet', 'servletName': 'Restaurant_Review', 'modules': ["deferred/lateHandlers","handlers"], 'params': {"typeahead_to_store":{"typeahead_new_location_label":"NEW LOCATION","typeahead.aliases.travel_insurance":["insurance","travel insurance","trip insurance","annual travel insurance"],"typeahead.aliases.flight_reviews":["flight reviews","airline reviews"],"typeahead_throttle_requests":"true","typeahead.aliases.rental_cars":["Rental Cars","Car Rentals"],"typeahead_cruise_ships_enabled":"true","typeahead.aliases.activities":["Tours and Tickets","Tours & Tickets"],"typeahead.aliases.things_to_do":["Things to do","Thing to do","attractions","activities","what to do","sightseeing","Sights","Tourist Attractions","Activity","Attraction","What to see","Where to go","Where to visit","Best Attractions","Best Things to do","Best Tourist Attractions","Best Sightseeing","Top Attractions","Top Things to do","Top Tourist Attractions","Top Sightseeing","Top 10 Attractions","Top 10 Things to do","Top 10 Tourist Attractions","Top 10 Sightseeing"],"typeahead.enable_nearby":true,"typeahead_cruise_cruiselines_enabled":"true","typeahead_divClasses":null,"typeahead.scoped.cur_loc_denied":"Tripadvisor was denied permission to access your location.  Give your browser and Tripadvisor permission to use your current location and try again.","typeahead.scoped.cur_loc":"Nearby","typeahead.aliases.travel_forums":["forum","forums","Travel Forum","Travel Forums"],"typeahead.aliases.travel_guides":["guides","city guides"],"typeahead.aliases.vacation_rentals":["vacation rentals","vacation rental","Airbnb","Holiday rental","Holiday rentals"],"typeahead.aliases.flights":["Flights","Flight","Flight to","flights to","nonstop flights","business class flights","return flights","airline flights","air flights","cheap flights","flight from","cheapest flights","flight only","one way flights","direct flights","domestic flights","air fare","cheap flights to","air flights to","airline flights to","business class flights to","cheapest flights to","direct flights to","domestic flights to","nonstop flights to","one way flights to","air fares","airfare","airfares","air fare to","air fares to","airfare to","airfares to"],"typeahead_moved_label":"MOVED","typeahead_dual_search_options":{"geoID":35790,"bypassSearch":true,"staticTypeAheadOptions":{"minChars":3,"defaultValue":"Search","injectNewLocation":true,"typeahead1_5":true,"geoBoostFix":true},"debug":false,"navSearchTypeAheadEnabled":true,"isMobileWeb":false,"geoInfo":{"geoId":35790,"geoName":"Champaign","parentName":"Illinois","shortParentName":"Illinois","categories":{"GEO":{"url":"/Tourism-g35790-Champaign_Champaign_Urbana_Illinois-Vacations.html"},"HOTEL":{"url":"/Hotels-g35790-Champaign_Champaign_Urbana_Illinois-Hotels.html"},"VACATION_RENTAL":{"url":"/VacationRentals-g35790-Reviews-Champaign_Champaign_Urbana_Illinois-Vacation_Rentals.html"},"ATTRACTION":{"url":"/Attractions-g35790-Activities-Champaign_Champaign_Urbana_Illinois.html"},"EATERY":{"url":"/Restaurants-g35790-Champaign_Champaign_Urbana_Illinois.html"},"FLIGHTS_TO":{"url":"/Flights-g35790-Champaign_Champaign_Urbana_Illinois-Cheap_Discount_Airfares.html"},"CAR_RENTAL_OFFICE":{"url":"/RentalCars_Review?detail=35790"}}}},"typeahead_closed_label":"CLOSED","typeahead.scoped.all_of_trip":"Worldwide","typeahead_attraction_activity_search":"true","typeahead.aliases.hotels":["hotels","hotel","lodging","places to stay","where to stay","accommodation","accommodations","hotel reviews","Hotels & Motels","Best Hotels","Best Places to Stay","Best Lodging","Best Hotels & Motels","Lodgings","Place to stay","Top Hotels","Top Places to Stay","Top Lodging","Top Hotels & Motels","Top 10 Hotels","To ...
# require(['ta/p13n/placements','ta/page','$prp/browser_mode_tracking/handlers'], function(placements, impl) {
# window.ta.plc_browser_mode_tracking_0_handlers = placements.load('browser_mode_tracking','handlers.js', { 'name': 'browser_mode_tracking', 'occurrence': 0, 'id': 'taplc_browser_mode_tracking_0', 'location_id': 2010890, 'servletClass': 'com.TripResearch.servlet.eatery.responsive.RestaurantReviewServlet', 'servletName': 'Restaurant_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/qualtrics_survey/handlers'], function(placements, impl) {
# window.ta.plc_qualtrics_survey_0_handlers = placements.load('qualtrics_survey','handlers.js', { 'name': 'qualtrics_survey', 'occurrence': 0, 'id': 'taplc_qualtrics_survey_0', 'location_id': 2010890, 'servletClass': 'com.TripResearch.servlet.eatery.responsive.RestaurantReviewServlet', 'servletName': 'Restaurant_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/effective_measures/handlers'], function(placements, impl) {
# window.ta.plc_effective_measures_apac_0_handlers = placements.load('effective_measures','handlers.js', { 'name': 'effective_measures:apac', 'occurrence': 0, 'id': 'taplc_effective_measures_apac_0', 'location_id': 2010890, 'servletClass': 'com.TripResearch.servlet.eatery.responsive.RestaurantReviewServlet', 'servletName': 'Restaurant_Review', 'modules': ["handlers"], 'params': {"host_prefix":"sg"}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/masthead_h1/handlers'], function(placements, impl) {
# window.ta.plc_masthead_h1_rr_resp_0_handlers = placements.load('masthead_h1','handlers.js', { 'name': 'masthead_h1:rr_resp', 'occurrence': 0, 'id': 'taplc_masthead_h1_rr_resp_0', 'location_id': 2010890, 'servletClass': 'com.TripResearch.servlet.eatery.responsive.RestaurantReviewServlet', 'servletName': 'Restaurant_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/p13n/placements','ta/page','$prp/trip_planner_breadcrumbs/handlers'], function(placements, impl) {
# window.ta.plc_trip_planner_breadcrumbs_0_handlers = placements.load('trip_planner_breadcrumbs','handlers.js', { 'name': 'trip_planner_breadcrumbs', 'occurrence': 0, 'id': 'taplc_trip_planner_breadcrumbs_0', 'location_id': 2010890, 'servletClass': 'com.TripResearch.servlet.eatery.responsive.RestaurantReviewServlet', 'servletName': 'Restaurant_Review', 'modules': ["handlers"], 'params': {}, 'data': {}});});
# require(['ta/prwidgets', 'ta/page'], function(prwidgets) {
# prwidgets.initWidgets(document);
# });
#   </script>
#   <script>
#    require(['servlets/standardTemplateSupport'], function(support) {support.footerInit();});
#   </script>
#   <!-- PLACEMENT effective_measures:apac -->
#   <div class="ppr_rup ppr_priv_effective_measures" data-placement-name="effective_measures:apac" id="taplc_effective_measures_apac_0">
#    <noscript>
#     <img alt="" src="//.effectivemeasure.net/em_image" style="position:absolute; left:-5px;"/>
#    </noscript>
#   </div>
#   <!-- PLACEMENT sync_rt_cookie -->
#   <div class="ppr_rup ppr_priv_sync_rt_cookie" data-placement-name="sync_rt_cookie" id="taplc_sync_rt_cookie_0">
#    <script type="text/javascript">
#     require(["ta/Core/TA.Store"], function(taStore) {taStore.store("retargeting.rtURL", '//' + 'www.tamgrt.com/RT');taStore.store("retargeting.drs", 'ABC.81*AFIL.79*ATTPromo.14*AUC.31*BBML.73*BMP.3*BRDTTD.6*Brand.75*CAKE.18*CAR.54*COM.97*CRS.46*Community.79*Content.56*CoreX.73*EATPIZZA.48*EID.38*EXP.31*Engage.37*FDP.25*FDS.65*FDU.37*FLTMERCH.5*FLTREV.64*Filters.96*Flights.50*HRATF.37*HSX.10*HSXB.10*IBEX.17*ING.68*INT1.56*INT2.61*ITR.76*L10N.94*ML.59*ML6.4*MM.32*MOBILEAPP.-1*MOF.75*MPS.75*MTA.32*Me2.91*Mem.99*Mobile.98*MobileCore.12*Notifications.79*Other.66*P13N.51*PIE.86*PLS.22*POS.30*PRT.21*RDS1.20*RDS2.15*RDS3.23*RDS4.70*RDS5.65*RET.58*REV.52*REVB.13*REVH.50*REVM.37*REVSD.39*REVSP.7*REVXS.33*RNA.21*RSE1.78*RSE2.28*Rooms.38*S3PO.32*SD40.75*SE2O.37*SEM.59*SEO.79*SORT1.27*Sales.95*Search.89*SiteX.85*Surveys.12*T4B.78*TGT.92*TRP.92*TTD.84*TX.84*Timeline.15*VP.45*VR.41*YM.81*YMB.14');taStore.store("retargeting.geoId", '35790');});
#    </script>
#    <script type="text/javascript">
#     (function(window, document) {"use strict";var SYNC_AGE = 1000*60*30; var WHITELIST_AGE = 1000*60*60*24; var HTTP_COOKIE = "TART";var SYNC_COOKIE = "SRT";var WHITELIST_COOKIE = "WLRedir";var MSG_PREFIX = "COOKIESYNC:";var _isNewRTCookie = true;var _tart = 'enc%3ABVwk8wouSwq3SU7A1QMl2nqQUMld3odNs8efjx7Qa1L7nKwsJBuWpXjNqOv5CNm0WgczmCiRtcQ%3D';if (_hasCookie(HTTP_COOKIE) && !_isNewRTCookie) { return; } var syncFrame = document.createElement('iframe');function _on(element, event, callback) {var legacy = !('addEventListener' in document),   listen = legacy ? 'attachEvent' : 'addEventListener';if (legacy) { event = 'on' + event; }element[listen](event, callback);}function _off(element, event, callback) {var legacy = !('addEventListener' in document),   detach = legacy ? 'detachEvent' : 'removeEventListener';if (legacy) { event = 'on' + event; }element[detach](event, callback);}function _setCookie(name, value, age) {document.cookie = name + '=' + value +';domain=' + window.location.hostname +';path=/' +';expires=' + new Date(new Date().getTime() + age).toUTCString();}function _hasCookie(name) {return !!document.cookie.match(name + '=[^;]+');}function handleMessage(e) {if (!syncFrame || !e || !e.data || !e.data.indexOf || e.data.indexOf(MSG_PREFIX) !== 0) { return; }var cookieValue = e.data.substring(MSG_PREFIX.length);if (cookieValue) {_setCookie(SYNC_COOKIE, cookieValue, SYNC_AGE);} else if(!_hasCookie(WHITELIST_COOKIE)) {_setCookie(WHITELIST_COOKIE, "requested", WHITELIST_AGE);}_off(window, 'message', handleMessage);document.body.removeChild(syncFrame);syncFrame = null;}function _setupSyncFrame() {if (!syncFrame) { return; }var src = window.location.protocol + '//' + 'www.tamgrt.com/RT' + "?-sync=true&q=" + new Date().getTime();if(_isNewRTCookie) {if(_tart) {src += '&rid=' + _tart;}}syncFrame.src = src;document.body.appendChild(syncFrame);}_on(window, 'message', handleMessage);syncFrame.style.display = 'none';syncFrame.id = 'ta_cookie_sync';syncFrame.name = new Date().getTime();_setupSyncFrame();})(window, document);
#    </script>
#   </div>
#   <!-- PLACEMENT enable_cpm_desktop -->
#   <div class="ppr_rup ppr_priv_enable_cpm_desktop" data-placement-name="enable_cpm_desktop" id="taplc_enable_cpm_desktop_0">
#    <style>
#     .gptAd {position: relative;width: 100%; text-align: center;margin-left: auto;margin-right: auto;}.gptAd > div, .gptAd > div > iframe {display: block !important;margin-left: auto;margin-right: auto;}
#    </style>
#    <script>
#     window.googletag = window.googletag || {cmd:[]};  window.addEventListener('load', function() { var initOpts = {gptBase: "/5349/ta.ta.tw.s/na.us.illinois",gptConfig: {"adTrackingConfig":{"56115731":"Onyx","125294291":"Onyx","439801571":"Onyx","439513691":"Onyx","268297691":"Onyx","146529491":"Onyx","56043851":"Onyx","55678451":"Hotwire","55721291":"Choice","55752491":"Choice","56107811":"Rakuten","444557411":"Rakuten"},"enable_rubicon_bidding":true,"defer_bidding_call":true,"visibility_change_refresh":true,"enable_deferred_ads":true},   pageTargeting: {"country":["191"],"drs":["BRAND_75","FL_50","SALES_95","P13N_51","PRT_21","SEARCH_89"],"d":["CMI"],"sess":["B45BD3E68B0FCE0DA7E22E28E0357A55"],"cuisine":["Taiwanese","Chinese","Asian"],"kw":["Golden_Harbor"],"loctype":["restaurants"],"platform":["desktop"],"dregion":["35790"],"o":["TPE"],"aud_id":["15873","16062","16671","15315","16336","16635","15440","16860"],"geo":["35790"],"r":["TPECMI"],"rd":["com"],"pv_id":["X4HnhwokGScAARMP2RIAAADh"],"oregion":["293913"],"detail":["2010890"],"region":["3511549","28934"],"PageType":["Restaurant_Review"],"hname":["Golden_Harbor"]},      adStubs: {"adTypes":[{"tgt":"gpt-ad-728x90-970x66","size":[[728,90],[970,66],"fluid"],"type":"leaderboard_top","rubicon_prebid":true,"base":"/5349/ta.ta.tw.s/na.us.illinois","custom_targeting":{"pos":["top"],"fluidType":"banner"}},{"tgt":"gpt-ad-3x1-globalnav","size":[[3,1]],"type":"other","isHidden":true,"base":"/5349/ta.ta.tw.s/na.us.illinois","custom_targeting":{"pos":["globalnav"],"kw":"lure","disable_event_refresh":true}},{"tgt":"gpt-ad-3x1-tripsearch","size":[[3,1]],"type":"other","isHidden":true,"base":"/5349/ta.ta.tw.s/na.us.illinois","custom_targeting":{"pos":["tripsearch"],"kw":"lure","disable_event_refresh":true}},{"tgt":"gpt-ad-3x1-quicklinks","size":[[3,1]],"type":"other","isHidden":true,"base":"/5349/ta.ta.tw.s/na.us.illinois","custom_targeting":{"pos":["quicklinks"],"kw":"lure","disable_event_refresh":true}},{"tgt":"gpt-ad-728x90-970x66-header","size":[[728,90],[970,66],"fluid"],"type":"leaderboard_header","rubicon_prebid":true,"base":"/5349/ta.ta.tw.s/na.us.illinois","custom_targeting":{"pos":["header"],"fluidType":"banner"}},{"tgt":"gpt-ad-300x250-300x600-rail1","size":[[300,250],[300,600],"fluid"],"type":"medium_rectangle_rail1","rubicon_prebid":true,"base":"/5349/ta.ta.tw.s/na.us.illinois","custom_targeting":{"pos":["rail1"],"fluidType":"rail"}},{"tgt":"gpt-ad-300x250-300x600-rail2","size":[[300,250],[300,600],"fluid"],"type":"medium_rectangle_rail2","rubicon_prebid":true,"base":"/5349/ta.ta.tw.s/na.us.illinois","custom_targeting":{"pos":["rail2"],"fluidType":"rail"}},{"tgt":"gpt-ad-970x250-728x90-footer","size":[[970,250],[728,90],"fluid"],"type":"leaderboard_footer","rubicon_prebid":true,"base":"/5349/ta.ta.tw.s/na.us.illinois","custom_targeting":{"pos":["footer"],"fluidType":"banner"}}]}};      function getFirstAdTop() {try {  if (!initOpts.gptConfig.enable_deferred_ads) {return 0;}var firstAd;var ads = [].slice.call(document.querySelectorAll('.gptAd')).filter(function(ad) { return !!ad.offsetParent; });if(ads.length && ads[0].getBoundingClientRect) {return ads.reduce(function(min, el){ return Math.min(min, el.getBoundingClientRect().top);}, Infinity);}} catch(e) {return 0;}}var FIRST_AD_TOP = getFirstAdTop();var initHasRun = false;var apiTrigger = window.innerHeight; function initAtFirstAd(){if (window.pageYOffset > FIRST_AD_TOP - apiTrigger) {window.removeEventListener('scroll', initAtFirstAd);if (!initHasRun) {initHasRun = true;require(['@ta/platform.runtime', 'trjs!cpm/Desktop'], function(runtime, desktopAds) {runtime.importBundle('@ta/platform.consent').then(function (bundle) {bundle.requestConsent(bundle.CategoriesEnum.ADVERTISING, function() {desktopAds.initDoubleClick(initOpts); });});});}}}initAtFirstAd();window.addEventListener('scroll', initAtFirstAd);});
#    </script>
#   </div>
#   <!-- PLACEMENT ab_chk -->
#   <div class="ppr_rup ppr_priv_ab_chk" data-placement-name="ab_chk" id="taplc_ab_chk_0">
#   </div>
#  </body>
# </html>

# %%
# sometimes div classes are just not intuitively named 
# here's an instance of one of the reviews
print(soup.find('div', class_="ui_column is-9").prettify())

# Looks like the useful tags we can get are 
# "quote": -------------------------------- a div tag
# "partial_entry": ------------------------ a p tag
# "prw_rup prw_reviews_stay_date_hsx": ---- a div tag
# "ui_bubble_rating..." ------------------- a span tag (this last one's a bit weird)
# Out:
# <div class="ui_column is-9">
#  <span class="ui_bubble_rating bubble_50">
#  </span>
#  <span class="ratingDate" title="February 1, 2020">
#   Reviewed February 1, 2020
#  </span>
#  <div class="quote">
#   <a class="title " href="/ShowUserReviews-g35790-d2010890-r742485483-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" id="rn742485483" onclick="(ta.prwidgets.getjs(this,'handlers')).reviewClick(this.href, '0');">
#    <span class="noQuotes">
#     Chinese food
#    </span>
#   </a>
#  </div>
#  <div class="prw_rup prw_reviews_text_summary_hsx" data-prwidget-init="handlers" data-prwidget-name="reviews_text_summary_hsx">
#   <div class="entry">
#    <p class="partial_entry">
#     the best Chinese in Champaign-Urbana.....very fresh and many choices on the menue....highly recommend.
#    </p>
#   </div>
#  </div>
#  <div class="prw_rup prw_reviews_stay_date_hsx" data-prwidget-init="" data-prwidget-name="reviews_stay_date_hsx">
#   <span class="stay_date_label">
#    Date of visit:
#   </span>
#   December 2019
#  </div>
#  <div class="prw_rup prw_reviews_vote_line_hsx" data-prwidget-deferred="deferred/clicks" data-prwidget-init="handlers" data-prwidget-name="reviews_vote_line_hsx">
#   <div class="tooltips wrap">
#    <span class="taLnk no_cpu ui_icon flag" data-content="Problem with this review?" data-position="above" data-tooltip="" id="ReportIAP_742485483" onclick="ta.prwidgets.call('deferred/clicks.clickReport',event,this,742485483,'member');return false;" onmouseover="widgetEvCall('handlers.hoverReport',event,this);return false;">
#    </span>
#   </div>
#   <div class="helpful redesigned hsx_helpful">
#    <span class="isHelpful">
#     Helpful?
#    </span>
#    <span class="thankButton hsx_thank_button" onclick="ta.prwidgets.call('deferred/clicks.clickThank',event,this,'...');return false;">
#     <span class="helpful_text">
#      <span class="ui_icon thumbs-up cx_brand_refresh_phase2 ">
#      </span>
#      <span class="numHelp ">
#      </span>
#     </span>
#     <div class="buttonShade hidden">
#      <img alt="" src="https://static.tacdn.com/img2/generic/site/loading_anim_gry_sml.gif"/>
#     </div>
#    </span>
#   </div>
#  </div>
#  <div class="loadingShade hidden">
#   <div class="ui_spinner">
#   </div>
#  </div>
# </div>

# %% [markdown]
# ### Great! Now we can get started actually using this data.

# %%
# Luckily there's a handy-dandy find_all() function in bs4

soups = soup.find_all('div', class_="ui_column is-9")
print(soups)
# Out:
# [<div class="ui_column is-9"><span class="ui_bubble_rating bubble_50"></span><span class="ratingDate" title="February 1, 2020">Reviewed February 1, 2020 </span><div class="quote"><a class="title " href="/ShowUserReviews-g35790-d2010890-r742485483-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" id="rn742485483" onclick="(ta.prwidgets.getjs(this,'handlers')).reviewClick(this.href, '0');"><span class="noQuotes">Chinese food</span></a></div><div class="prw_rup prw_reviews_text_summary_hsx" data-prwidget-init="handlers" data-prwidget-name="reviews_text_summary_hsx"><div class="entry"><p class="partial_entry">the best Chinese in Champaign-Urbana.....very fresh and many choices on the menue....highly recommend.</p></div></div><div class="prw_rup prw_reviews_stay_date_hsx" data-prwidget-init="" data-prwidget-name="reviews_stay_date_hsx"><span class="stay_date_label">Date of visit:</span> December 2019</div><div class="prw_rup prw_reviews_vote_line_hsx" data-prwidget-deferred="deferred/clicks" data-prwidget-init="handlers" data-prwidget-name="reviews_vote_line_hsx"><div class="tooltips wrap"><span class="taLnk no_cpu ui_icon flag" data-content="Problem with this review?" data-position="above" data-tooltip="" id="ReportIAP_742485483" onclick="ta.prwidgets.call('deferred/clicks.clickReport',event,this,742485483,'member');return false;" onmouseover="widgetEvCall('handlers.hoverReport',event,this);return false;"></span></div><div class="helpful redesigned hsx_helpful"><span class="isHelpful">Helpful?</span><span class="thankButton hsx_thank_button" onclick="ta.prwidgets.call('deferred/clicks.clickThank',event,this,'...');return false;"><span class="helpful_text"><span class="ui_icon thumbs-up cx_brand_refresh_phase2 "></span><span class="numHelp "></span></span><div class="buttonShade hidden"><img alt="" src="https://static.tacdn.com/img2/generic/site/loading_anim_gry_sml.gif"/></div></span></div></div><div class="loadingShade hidden"><div class="ui_spinner"></div></div></div>, <div class="ui_column is-9"><span class="ui_bubble_rating bubble_40"></span><span class="ratingDate" title="October 8, 2019">Reviewed October 8, 2019 </span><div class="quote"><a class="title " href="/ShowUserReviews-g35790-d2010890-r716476924-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html" id="rn716476924" onclick="(ta.prwidgets.getjs(this,'handlers')).reviewClick(this.href, '0');"><span class="noQuotes">One of the best Chinese restaurants in Champaign</span></a></div><div class="prw_rup prw_reviews_text_summary_hsx" data-prwidget-init="handlers" data-prwidget-name="reviews_text_summary_hsx"><div class="entry"><p class="partial_entry">Great chi ese food. Try the whole fish and some spicy dish. The home made tofu was impressive.  Many many choices and not sure how the chef can cook so many different dishes</p></div></div><div class="prw_rup prw_reviews_stay_date_hsx" data-prwidget-init="" data-prwidget-name="reviews_stay_date_hsx"><span class="stay_date_label">Date of visit:</span> August 2019</div><div class="prw_rup prw_reviews_vote_line_hsx" data-prwidget-deferred="deferred/clicks" data-prwidget-init="handlers" data-prwidget-name="reviews_vote_line_hsx"><div class="tooltips wrap"><span class="taLnk no_cpu ui_icon flag" data-content="Problem with this review?" data-position="above" data-tooltip="" id="ReportIAP_716476924" onclick="ta.prwidgets.call('deferred/clicks.clickReport',event,this,716476924,'member');return false;" onmouseover="widgetEvCall('handlers.hoverReport',event,this);return false;"></span></div><div class="helpful redesigned hsx_helpful"><span class="isHelpful">Helpful?</span><span class="thankButton hsx_thank_button" onclick="ta.prwidgets.call('deferred/clicks.clickThank',event,this,'...');return false;"><span class="helpful_text"><span class="ui_icon thumbs-up cx_brand_refresh_phase2 "></span><span class="numHelp "></span></span><div class="buttonShade hidden"><img alt="" src="https://static.tacdn.com/img2/generic/site/loading_ani ...

# %% [markdown]
# #### One thing to keep an eye out for.

# %%
# You'll notice something weird about the length of this list of reviews

print(len(soups))
# Out:
# 10

# %% [markdown]
# #### Be careful of "next page" buttons and the like when you're trying to scrape things like reviews from a page.

# %%
# Here's some code we wrote to go through every page in TripAdvisor
# We're not super worried about runtime here since the amount of reviews is small but be careful in larger datasets
link_front_half = "https://www.tripadvisor.com/Restaurant_Review-g35790-d2010890-Reviews-"
link_back_half = "-Golden_Harbor-Champaign_Champaign_Urbana_Illinois.html"

page = 0
while True:
    review_page_num = f"or{page}0"
    golden_harbor_link = link_front_half + review_page_num + link_back_half
    r = requests.get(golden_harbor_link, allow_redirects = True)

    # r.history checks the redirects
    # if there is a redirect, we must have gone past the last availablge page
    # (with an exception for page 0, which redirects to the first page)
    if page != 0 and len(r.history) > 0:
        break
    
    soup = BeautifulSoup(r.content, 'html.parser')
    reviews = soup.find_all('div', class_="ui_column is-9")
    print(f"Page {page}: Adding {len(reviews)} reviews")
    soups += reviews
    page += 1
# Out:
# Page 0: Adding 10 reviews
# Page 1: Adding 10 reviews
# Page 2: Adding 10 reviews
# Page 3: Adding 10 reviews
# Page 4: Adding 10 reviews
# Page 5: Adding 10 reviews
# Page 6: Adding 10 reviews
# Page 7: Adding 10 reviews
# Page 8: Adding 10 reviews
# Page 9: Adding 10 reviews
# Page 10: Adding 10 reviews
# Page 11: Adding 6 reviews

# %%
# Cool! That matches the review count
len(soups)
# Out:
# 126

# %% [markdown]
# ### Now it's just time to put everything together...

# %%
# Let's take a look at how we can get the values we want

soup = soups[0] # Just using the first soup as an example

soup.span.clear()

date_of_visit = soup.find("div", class_="prw_rup prw_reviews_stay_date_hsx").contents[-1].strip() # something weird happens here!

title = soup.find('div', class_="quote").get_text() # these two tags were nice

review_text = soup.find("p", class_="partial_entry").get_text()

rating = soup.find("span", class_= lambda value: value and value.startswith("ui_bubble_rating"))['class'] # something weird also happens here!
rating = rating[1][7:]
rating = float(rating) / 10

print(date_of_visit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1f86c647c7e5> in <module>()
#       1 # Let's take a look at how we can get the values we want
#       2
# ----> 3 soup = soups[0] # Just using the first soup as an example
#       4
#       5 soup.span.clear()
#
# NameError: name 'soups' is not defined

# %%
# Let's loop through each one of the soups first and put the useful parts into a list

data_tuples = []

for soup in soups:
    try:
        date_of_visit = soup.find("div", class_="prw_rup prw_reviews_stay_date_hsx").contents[-1].strip() # something weird happens here!
    except:
        date_of_visit = ""

    title = soup.find('div', class_="quote").get_text() # these two tags were nice
    review_text = soup.find("p", class_="partial_entry").get_text()
    rating = soup.find("span", class_= lambda value: value and value.startswith("ui_bubble_rating"))['class'] # something weird also happens here!
    rating = rating[1][7:]
    rating = float(rating) / 10

    to_add = (date_of_visit, title, review_text, rating)
    data_tuples.append(to_add)

# %%
import pandas as pd
import numpy as np

golden_harbor_data = pd.DataFrame(data_tuples, columns = ["date_of_visit", "title", "review_text", "rating"])

golden_harbor_data = golden_harbor_data.fillna("") # takes care of blank values
golden_harbor_data
# Out:
#       date_of_visit  ... rating
# 0     December 2019  ...    5.0
# 1       August 2019  ...    4.0
# 2    September 2019  ...    5.0
# 3         July 2019  ...    4.0
# 4         July 2019  ...    4.0
# ..              ...  ...    ...
# 121   December 2011  ...    4.0
# 122   November 2011  ...    4.0
# 123  September 2011  ...    4.0
# 124     August 2011  ...    3.0
# 125    January 2011  ...    2.0
#
# [126 rows x 4 columns]

# %%
# Let's do some sentiment analysis!
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
analyzer = SentimentIntensityAnalyzer()

sentiments = []

for review in golden_harbor_data["review_text"]:
    vs = analyzer.polarity_scores(review)
    print(f"review: '{review[:min(75,len(review))]}...'\nsentiment: {vs}\n")
    neg, neu, pos, compound = vs.values()
    sentiments.append(compound)

golden_harbor_data["sentiment"] = sentiments
# Out:
# review: 'the best Chinese in Champaign-Urbana.....very fresh and many choices on the...'
# sentiment: {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.8402}
#
# review: 'Great chi ese food. Try the whole fish and some spicy dish. The home made t...'
# sentiment: {'neg': 0.05, 'neu': 0.762, 'pos': 0.188, 'compound': 0.7534}
#
# review: 'I've heard so much about Golden Harbor and it lived up to all expectations....'
# sentiment: {'neg': 0.0, 'neu': 0.913, 'pos': 0.087, 'compound': 0.7346}
#
# review: 'We visited with a large group and with an individual who lives in China. Sh...'
# sentiment: {'neg': 0.0, 'neu': 0.895, 'pos': 0.105, 'compound': 0.5709}
#
# review: 'Old-fashioned Chinese family restaurant.  You fill out a slip with your ord...'
# sentiment: {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.4927}
#
# review: 'They have two menus, one for your standard American Chinese food, and one f...'
# sentiment: {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.8042}
#
# review: 'The food is exquisite: fresh, organic (many ingredients), and tasty. The be...'
# sentiment: {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.8555}
#
# review: 'We’ve been eating here for years and the food is fast and delicious.  Recen...'
# sentiment: {'neg': 0.0, 'neu': 0.871, 'pos': 0.129, 'compound': 0.6187}
#
# review: 'They have way too many dishes, so hard to select.....they are all good if y...'
# sentiment: {'neg': 0.072, 'neu': 0.822, 'pos': 0.106, 'compound': 0.3682}
#
# review: 'Very large group/family oriented restaurant with a huge menu.  Our food was...'
# sentiment: {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.6369}
#
# review: 'the best Chinese in Champaign-Urbana.....very fresh and many choices on the...'
# sentiment: {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.8402}
#
# review: 'Great chi ese food. Try the whole fish and some spicy dish. The home made t...'
# sentiment: {'neg': 0.05, 'neu': 0.762, 'pos': 0.188, 'compound': 0.7534}
#
# review: 'I've heard so much about Golden Harbor and it lived up to all expectations....'
# sentiment: {'neg': 0.0, 'neu': 0.913, 'pos': 0.087, 'compound': 0.7346}
#
# review: 'We visited with a large group and with an individual who lives in China. Sh...'
# sentiment: {'neg': 0.0, 'neu': 0.895, 'pos': 0.105, 'compound': 0.5709}
#
# review: 'Old-fashioned Chinese family restaurant.  You fill out a slip with your ord...'
# sentiment: {'neg': 0.0, 'neu': 0.891, 'pos': 0.109, 'compound': 0.4927}
#
# review: 'They have two menus, one for your standard American Chinese food, and one f...'
# sentiment: {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.8042}
#
# review: 'The food is exquisite: fresh, organic (many ingredients), and tasty. The be...'
# sentiment: {'neg': 0.0, 'neu': 0.755, 'pos': 0.245, 'compound': 0.8555}
#
# review: 'We’ve been eating here for years and the food is fast and delicious.  Recen...'
# sentiment: {'neg': 0.0, 'neu': 0.871, 'pos': 0.129, 'compound': 0.6187}
#
# review: 'They have way too many dishes, so hard to select.....they are all good if y...'
# sentiment: {'neg': 0.072, 'neu': 0.822, 'pos': 0.106, 'compound': 0.3682}
#
# review: 'Very large group/family oriented restaurant with a huge menu.  Our food was...'
# sentiment: {'neg': 0.0, 'neu': 0.856, 'pos': 0.144, 'compound': 0.6369}
#
# review: 'Don't expect to be served.  You write down your order, take it to the count...'
# sentiment: {'neg': 0.062, 'neu': 0.898, 'pos': 0.041, 'compound': -0.25}
#
# review: 'This is a small, somewhat unique place near downtown Champaign. There are n...'
# sentiment: {'neg': 0.0, 'neu': 0.821, 'pos': 0.179, 'compound': 0.8462}
#
# review: 'That's the second time in a week that I went to a restaurant in which I wou...'
# sentiment: {'neg': 0.063, 'neu': 0.857, 'pos': 0.08, 'compound': -0.0539}
#
# review: 'All food ordered was good--served to share on big rotating table server.  T...'
# sentiment: {'neg': 0.111, 'neu': 0.844, 'pos': 0.045, 'compound': -0.296}
#
# review: 'My experience has led me to conclude that the best menu has only 20-30 item...'
# sentiment: {'neg': 0.057, 'neu': 0.756, 'pos': 0.187, 'compound': 0.7929}
#
# review: 'They have the best-minced pork, jalapeno noodles ever - anywhere. Don't lea...'
# sentiment: {'neg': 0.0, 'neu': 0.937, 'pos': 0.063, 'compound': 0.0382}
#
# review: 'Lunch for 7 people after graduation. The menu was full and rich. Service wa...'
# sentiment: {'neg': 0.0, 'neu': 0.713, 'pos': 0.287, 'compound': 0.9201}
#
# review: 'This is one of my favorite restaurant. it has variety of food with reasonab...'
# sentiment: {'neg': 0.0, 'neu': 0.87, 'pos': 0.13, 'compound': 0.4588}
#
# review: 'They have Americanized menu and regular Chinese menu up to 1300+ items to c...'
# sentiment: {'neg': 0.048, 'neu': 0.952, 'pos': 0.0, 'compound': -0.3031}
#
# review: 'Had take out from Golden Harbor and was amazed at the size of the portions....'
# sentiment: {'neg': 0.0, 'neu': 0.926, 'pos': 0.074, 'compound': 0.5411}
#
# review: 'What a wonderful way to celebrate Chinese New Year with its own special men...'
# sentiment: {'neg': 0.0, 'neu': 0.707, 'pos': 0.293, 'compound': 0.9485}
#
# review: 'Ordered foods from dozens of wooden strips hung on the wall (in Chinese and...'
# sentiment: {'neg': 0.0, 'neu': 0.948, 'pos': 0.052, 'compound': 0.34}
#
# review: 'Golden Harbor was jammed with customers on this Friday evening. We ordered ...'
# sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# review: 'There's a giant menu on the wall in Chinese, but there are English menus on...'
# sentiment: {'neg': 0.0, 'neu': 0.726, 'pos': 0.274, 'compound': 0.9472}
#
# review: 'My entire family loves coming. The food is amazing, and authentic. My kids ...'
# sentiment: {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.9501}
#
# review: 'The order system is a bit odd, you take a guest check and write the number ...'
# sentiment: {'neg': 0.103, 'neu': 0.844, 'pos': 0.053, 'compound': -0.5267}
#
# review: 'The setup is pretty Spartan. It is a bit like a school lunch room. You just...'
# sentiment: {'neg': 0.025, 'neu': 0.869, 'pos': 0.106, 'compound': 0.4215}
#
# review: 'There is no ambiance.  Felt like being in a church fellowship hall with Sam...'
# sentiment: {'neg': 0.096, 'neu': 0.854, 'pos': 0.051, 'compound': -0.296}
#
# review: 'The service is very fast and the staff are so kind. I stopped in while visi...'
# sentiment: {'neg': 0.035, 'neu': 0.623, 'pos': 0.342, 'compound': 0.9692}
#
# review: 'We went whole family to this restaurant. It has huge menu ... it was not ea...'
# sentiment: {'neg': 0.049, 'neu': 0.855, 'pos': 0.096, 'compound': 0.3169}
#
# review: 'Went with family while visiting Urbana.  When you enter, you choose a table...'
# sentiment: {'neg': 0.0, 'neu': 0.9, 'pos': 0.1, 'compound': 0.5859}
#
# review: 'This was definitely a different restaurant.  When we first walked in we had...'
# sentiment: {'neg': 0.045, 'neu': 0.857, 'pos': 0.098, 'compound': 0.3818}
#
# review: 'Really great, freshly prepared Chinese food. The menu is so deep - it takes...'
# sentiment: {'neg': 0.083, 'neu': 0.725, 'pos': 0.192, 'compound': 0.6175}
#
# review: 'We went for dinner on a Saturday night.  It was crowded, but we shared one ...'
# sentiment: {'neg': 0.0, 'neu': 0.871, 'pos': 0.129, 'compound': 0.7469}
#
# review: 'We have eating here several times. We love the salt and pepper chicken, cri...'
# sentiment: {'neg': 0.026, 'neu': 0.796, 'pos': 0.178, 'compound': 0.771}
#
# review: 'My husband spent a semester abroad in China and was delighted to find this ...'
# sentiment: {'neg': 0.045, 'neu': 0.876, 'pos': 0.079, 'compound': 0.3987}
#
# review: 'Saturday afternoon late lunch wasn't too busy at all. We followed the instr...'
# sentiment: {'neg': 0.0, 'neu': 0.971, 'pos': 0.029, 'compound': 0.0772}
#
# review: 'I like to congratulate the owners of Golden Harbor, they are savvy enough t...'
# sentiment: {'neg': 0.027, 'neu': 0.792, 'pos': 0.181, 'compound': 0.8402}
#
# review: 'Went there when dropping our student off at U of I. Needless to say it was ...'
# sentiment: {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.7184}
#
# review: 'A friend recommended this restaurant to me, and I go nearly every time I am...'
# sentiment: {'neg': 0.028, 'neu': 0.82, 'pos': 0.152, 'compound': 0.7345}
#
# review: 'I'm used to quality Asian cuisine from the SF Bay Area and very disappointe...'
# sentiment: {'neg': 0.098, 'neu': 0.765, 'pos': 0.137, 'compound': 0.476}
#
# review: 'I've visited Golden Harbor a few times since my last review 5 years ago, an...'
# sentiment: {'neg': 0.0, 'neu': 0.798, 'pos': 0.202, 'compound': 0.8555}
#
# review: 'You choose your dish and write your own order. There is free tea if you lik...'
# sentiment: {'neg': 0.0, 'neu': 0.788, 'pos': 0.212, 'compound': 0.875}
#
# review: 'We like this restaurant very much.   The cooking is authentic and the porti...'
# sentiment: {'neg': 0.0, 'neu': 0.835, 'pos': 0.165, 'compound': 0.796}
#
# review: 'I visited this restaurant while in Champaign after hearing about it online....'
# sentiment: {'neg': 0.0, 'neu': 0.967, 'pos': 0.033, 'compound': 0.126}
#
# review: 'I haven't been in since they reopened, but I know it was an uncomfortable e...'
# sentiment: {'neg': 0.116, 'neu': 0.652, 'pos': 0.232, 'compound': 0.7909}
#
# review: 'I was visiting Banana-Champaign and was looking for a Chinese restaurant to...'
# sentiment: {'neg': 0.0, 'neu': 0.971, 'pos': 0.029, 'compound': 0.0772}
#
# review: 'Did I mention "FABULOUS!"?. Authentic setting as if back in china....kinda ...'
# sentiment: {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.9139}
#
# review: 'Great food and fun with the family. We kept on telling our sin how great it...'
# sentiment: {'neg': 0.213, 'neu': 0.532, 'pos': 0.255, 'compound': 0.5994}
#
# review: 'We got there near closing so we opted for takeout.  We had jalapeño chicken...'
# sentiment: {'neg': 0.069, 'neu': 0.931, 'pos': 0.0, 'compound': -0.296}
#
# review: 'I went there several times for the past 3 months and enjoyed the food there...'
# sentiment: {'neg': 0.028, 'neu': 0.842, 'pos': 0.13, 'compound': 0.7269}
#
# review: 'You know how everything is better with bacon. This translates to everything...'
# sentiment: {'neg': 0.0, 'neu': 0.868, 'pos': 0.132, 'compound': 0.7003}
#
# review: 'The food is authentic. Service prompt and friendly. Nothing elegant, just a...'
# sentiment: {'neg': 0.079, 'neu': 0.591, 'pos': 0.331, 'compound': 0.9426}
#
# review: 'Ordered multiple entrees for takeout from the Chinese menu (in English). Th...'
# sentiment: {'neg': 0.0, 'neu': 0.894, 'pos': 0.106, 'compound': 0.624}
#
# review: 'Don't be intimidated by the ordering process, you'll get through it just fi...'
# sentiment: {'neg': 0.0, 'neu': 0.677, 'pos': 0.323, 'compound': 0.7963}
#
# review: 'The menu at Golden Harbor is huge!  The décor is attractive and not overpow...'
# sentiment: {'neg': 0.0, 'neu': 0.759, 'pos': 0.241, 'compound': 0.8553}
#
# review: 'The most authentic Chinese food in C-U. Everything is super fresh, unique, ...'
# sentiment: {'neg': 0.027, 'neu': 0.731, 'pos': 0.242, 'compound': 0.8809}
#
# review: 'Food was fantastic, served steaming hot and family style. I couldn't believ...'
# sentiment: {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'compound': 0.8051}
#
# review: 'Order at the counter from an enormous menu, food is delivered family style ...'
# sentiment: {'neg': 0.048, 'neu': 0.784, 'pos': 0.168, 'compound': 0.743}
#
# review: 'Hundreds of dishes. All good so far!
# Great accommodations and is clean.
# wil...'
# sentiment: {'neg': 0.0, 'neu': 0.569, 'pos': 0.431, 'compound': 0.9368}
#
# review: 'Best in town. Tastes great and not too greasy like most Chinese restaurant ...'
# sentiment: {'neg': 0.086, 'neu': 0.676, 'pos': 0.239, 'compound': 0.8654}
#
# review: 'I have been going there for lunch or dinner for years. It is a family-run r...'
# sentiment: {'neg': 0.0, 'neu': 0.932, 'pos': 0.068, 'compound': 0.4927}
#
# review: 'YES! I could seriously eat here all the time... as long as I could find 6 f...'
# sentiment: {'neg': 0.031, 'neu': 0.705, 'pos': 0.264, 'compound': 0.9173}
#
# review: 'The inside is pretty bare bones with there being tables, order counter, dri...'
# sentiment: {'neg': 0.076, 'neu': 0.829, 'pos': 0.095, 'compound': -0.1528}
#
# review: 'Great place to have a nice friends or family dinner. If you are not sure wh...'
# sentiment: {'neg': 0.051, 'neu': 0.621, 'pos': 0.328, 'compound': 0.8942}
#
# review: 'The Chinese menu is overwhelming and the restaurant was full of Asian peopl...'
# sentiment: {'neg': 0.025, 'neu': 0.792, 'pos': 0.183, 'compound': 0.8481}
#
# review: 'Let me start by saying the service is A-plus, from ordering off the menu to...'
# sentiment: {'neg': 0.027, 'neu': 0.906, 'pos': 0.066, 'compound': 0.4287}
#
# review: 'This is a great Chinese restaurant. It is not fancy inside but the food is ...'
# sentiment: {'neg': 0.0, 'neu': 0.778, 'pos': 0.222, 'compound': 0.8934}
#
# review: 'This isn't your typical Chinese food that you would normally get delivered ...'
# sentiment: {'neg': 0.034, 'neu': 0.966, 'pos': 0.0, 'compound': -0.1419}
#
# review: 'I drove nearly 2 hrs to have lunch here. The website lured me with the mass...'
# sentiment: {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.7425}
#
# review: 'Visited for the first time because of good reviews! Very disappointed in ho...'
# sentiment: {'neg': 0.11, 'neu': 0.804, 'pos': 0.086, 'compound': -0.1986}
#
# review: 'Over salted and under cooked... The crispy chicken wasn't even crispy... Th...'
# sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# review: 'There are magic Chinese elves in the kitchen.  I don't know how all these a...'
# sentiment: {'neg': 0.0, 'neu': 0.79, 'pos': 0.21, 'compound': 0.9035}
#
# review: 'This restaurant serves the best Chinese food in town. The restaurant is qui...'
# sentiment: {'neg': 0.0, 'neu': 0.757, 'pos': 0.243, 'compound': 0.8107}
#
# review: 'I like the no non-sense approach of this place. From conveniently posted me...'
# sentiment: {'neg': 0.046, 'neu': 0.901, 'pos': 0.052, 'compound': 0.0772}
#
# review: 'We visit Champaign a few times a year to see family.  Golden Harbor is my "...'
# sentiment: {'neg': 0.0, 'neu': 0.973, 'pos': 0.027, 'compound': 0.0516}
#
# review: 'we went to Golden Harbor at Champaign, IL past Sunday. They have more than ...'
# sentiment: {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.5346}
#
# review: 'We chose Golden Harbor at random because the Mexican restaurant we were see...'
# sentiment: {'neg': 0.05, 'neu': 0.95, 'pos': 0.0, 'compound': -0.3164}
#
# review: 'I had no idea what kind of restaurant this was until I walked in the door. ...'
# sentiment: {'neg': 0.074, 'neu': 0.844, 'pos': 0.082, 'compound': 0.1027}
#
# review: 'The food was very fast and delicious.  We had shrimp and mixed vegetables. ...'
# sentiment: {'neg': 0.0, 'neu': 0.729, 'pos': 0.271, 'compound': 0.7939}
#
# review: 'We've liked just about everything we've had at GH. Portions are family-size...'
# sentiment: {'neg': 0.0, 'neu': 0.766, 'pos': 0.234, 'compound': 0.8981}
#
# review: 'With thousands (literally)  of items you cant go wrong.  If you want Americ...'
# sentiment: {'neg': 0.0, 'neu': 0.715, 'pos': 0.285, 'compound': 0.9267}
#
# review: 'This is a pretty good Chinese restaurant and in my experience the best Asia...'
# sentiment: {'neg': 0.0, 'neu': 0.81, 'pos': 0.19, 'compound': 0.8225}
#
# review: 'Went with a friend from Taiwan and ordered off the Chinese menu. There are ...'
# sentiment: {'neg': 0.0, 'neu': 0.82, 'pos': 0.18, 'compound': 0.8481}
#
# review: 'After checking reviews my wife and I decided to give it a try. Parking was ...'
# sentiment: {'neg': 0.0, 'neu': 0.911, 'pos': 0.089, 'compound': 0.4939}
#
# review: 'Ideally, bring someone who speaks Chinese and who can decipher the myriad o...'
# sentiment: {'neg': 0.087, 'neu': 0.825, 'pos': 0.087, 'compound': -0.2479}
#
# review: 'The ambience and the ordering process can put you off a bit but the food is...'
# sentiment: {'neg': 0.024, 'neu': 0.667, 'pos': 0.309, 'compound': 0.9642}
#
# review: 'Great place for Chinese food, if you have a Chinese-speaking member of your...'
# sentiment: {'neg': 0.0, 'neu': 0.675, 'pos': 0.325, 'compound': 0.957}
#
# review: 'This is not a restaurant for the casual Chinese food diner but an establish...'
# sentiment: {'neg': 0.0, 'neu': 0.793, 'pos': 0.207, 'compound': 0.8658}
#
# review: 'You get in and you feel in China.  Menu on the wall is in chinese.  They of...'
# sentiment: {'neg': 0.0, 'neu': 0.948, 'pos': 0.052, 'compound': 0.34}
#
# review: 'If you're looking for elegant atmosphere, fancy tablecloths, wait staff, et...'
# sentiment: {'neg': 0.0, 'neu': 0.858, 'pos': 0.142, 'compound': 0.7964}
#
# review: 'This is by far the best Chinese restaurant I have ever been too. If only th...'
# sentiment: {'neg': 0.0, 'neu': 0.818, 'pos': 0.182, 'compound': 0.7964}
#
# review: 'These are the must tries:
# 1. pancake wrapped pork.
# 2. all kinds of lamb.
# 3....'
# sentiment: {'neg': 0.0, 'neu': 0.863, 'pos': 0.137, 'compound': 0.54}
#
# review: 'Incredible selection of authentic food! This is one of the most authentic C...'
# sentiment: {'neg': 0.0, 'neu': 0.934, 'pos': 0.066, 'compound': 0.4753}
#
# review: 'From what I've been told by the international friends who have taken me her...'
# sentiment: {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'compound': 0.6597}
#
# review: 'After reading the reviews, a colleague and I walked from our hotel to this ...'
# sentiment: {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
# review: 'Like I am,  if you are a first timer,  you will be surprised by a full wall...'
# sentiment: {'neg': 0.0, 'neu': 0.907, 'pos': 0.093, 'compound': 0.5267}
#
# review: 'This restaurant makes very authentic and delicious Taiwanese food that will...'
# sentiment: {'neg': 0.0, 'neu': 0.888, 'pos': 0.112, 'compound': 0.6632}
#
# review: 'Golden Harbor is the opposite of fancy, but the food is genuine and wonderf...'
# sentiment: {'neg': 0.0, 'neu': 0.826, 'pos': 0.174, 'compound': 0.8338}
#
# review: 'Yes, I do agree with the reviews that say this is an unusual set-up & you d...'
# sentiment: {'neg': 0.0, 'neu': 0.689, 'pos': 0.311, 'compound': 0.9589}
#
# review: 'This restaurant is definately for the Asian communities and must really mak...'
# sentiment: {'neg': 0.031, 'neu': 0.941, 'pos': 0.028, 'compound': -0.0258}
#
# review: 'My niece who attended the U of I suggested this restaurant. Not at all what...'
# sentiment: {'neg': 0.0, 'neu': 0.976, 'pos': 0.024, 'compound': 0.0258}
#
# review: 'I come hear a lot. Huge menu with authentic Chinese food. The specialty is ...'
# sentiment: {'neg': 0.0, 'neu': 0.789, 'pos': 0.211, 'compound': 0.5859}
#
# review: 'Golden Harbor is one of the most authentic Chinese restaurant in the area. ...'
# sentiment: {'neg': 0.0, 'neu': 0.842, 'pos': 0.158, 'compound': 0.7845}
#
# review: 'I was there with some friends of mine, and at the beginning we were quite d...'
# sentiment: {'neg': 0.052, 'neu': 0.74, 'pos': 0.209, 'compound': 0.8176}
#
# review: 'Tina has run a series of absolutely divine Chinese restaurants in this area...'
# sentiment: {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.8218}
#
# review: 'My family loves eating at this restaurant. The first sign of an chinese aut...'
# sentiment: {'neg': 0.0, 'neu': 0.873, 'pos': 0.127, 'compound': 0.7394}
#
# review: 'Family style, entrees are generous, so order accordingly....'
# sentiment: {'neg': 0.0, 'neu': 0.68, 'pos': 0.32, 'compound': 0.5106}
#
# review: 'It is true, if you judge by the looks and the ordering system, this restaur...'
# sentiment: {'neg': 0.041, 'neu': 0.799, 'pos': 0.16, 'compound': 0.7263}
#
# review: 'All I can say is that this is one Chinese restaurant that we Chinese/Taiwan...'
# sentiment: {'neg': 0.0, 'neu': 0.86, 'pos': 0.14, 'compound': 0.705}
#
# review: 'i have eaten the before but i also work for the company the maintains the b...'
# sentiment: {'neg': 0.235, 'neu': 0.765, 'pos': 0.0, 'compound': -0.9311}
#
# review: 'A review earlier on this page calls the Golden Harbor a "dive" and gives it...'
# sentiment: {'neg': 0.0, 'neu': 0.959, 'pos': 0.041, 'compound': 0.2263}
#
# review: 'When you go to a chinese restaurant and the place is filled to the brim wit...'
# sentiment: {'neg': 0.0, 'neu': 0.954, 'pos': 0.046, 'compound': 0.2732}
#
# review: 'This restaurant is the real thing. Authentic Chinese food. Taiwanese style....'
# sentiment: {'neg': 0.0, 'neu': 0.914, 'pos': 0.086, 'compound': 0.6297}
#
# review: 'I ate lunch here with a work group of ten people. There is little service-y...'
# sentiment: {'neg': 0.031, 'neu': 0.969, 'pos': 0.0, 'compound': -0.1027}
#
# review: 'These people don't know how to run a restaurant.  They don't even know how ...'
# sentiment: {'neg': 0.0, 'neu': 0.867, 'pos': 0.133, 'compound': 0.8294}

# %%
golden_harbor_data
# Out:
#       date_of_visit  ... sentiment
# 0     December 2019  ...    0.8402
# 1       August 2019  ...    0.7534
# 2    September 2019  ...    0.7346
# 3         July 2019  ...    0.5709
# 4         July 2019  ...    0.4927
# ..              ...  ...       ...
# 121   December 2011  ...    0.2263
# 122   November 2011  ...    0.2732
# 123  September 2011  ...    0.6297
# 124     August 2011  ...   -0.1027
# 125    January 2011  ...    0.8294
#
# [126 rows x 5 columns]

# %%
# write data to a CSV file
golden_harbor_data.to_csv("golden_harbor_data.csv")

# %%
def insert_newlines(string: str, every: int = 50, newline_char: str = "<br>") -> str:
    """
    This function will insert `newline_char` into a string every `every` characters at
    the next available space character.

    this block of code will insert <br> (HTML break blocks) into our review_text strings
    which will format the plotly output (next cell)
    """
    for i in range(every, len(string), every):
        next_whitespace = string.find(" ", i)
        if next_whitespace != -1:
            string = string[:next_whitespace] + newline_char + string[(next_whitespace+1):]
    return string


golden_harbor_data["review_text_display"] = golden_harbor_data["review_text"].apply(insert_newlines)

# %%
# let's plot the data now!

import plotly.express as px


fig = px.scatter(golden_harbor_data,
                 x = "rating", y = "sentiment",
                 hover_name = "title",
                 hover_data = ["review_text_display"])
fig.update_layout(title = f"Ratings vs. Sentiment (n={len(golden_harbor_data)})",
                  xaxis_title = "Ratings ([1,5])",
                  yaxis_title = "Sentiment ([-1,1])")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b82f63bd-01cf-4032-9790-5fe4b1988fed" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b82f63bd-01cf-4032-9790-5fe4b1988fed")) {
#                     Plotly.newPlot(
#                         'b82f63bd-01cf-4032-9790-5fe4b1988fed',
#                         [{"customdata": [["the best Chinese in Champaign-Urbana.....very fresh<br>and many choices on the menue....highly recommend."], ["Great chi ese food. Try the whole fish and some spicy<br>dish. The home made tofu was impressive.  Many<br>many choices and not sure how the chef can cook<br>so many different dishes"], ["I've heard so much about Golden Harbor and it lived<br>up to all expectations. What is really surprising<br>is that the restaurant has a very large menu<br>and has still been able to maintain its quality.<br>We came in a big group and tried a...several<br>dishes, including sichuan type dry fish, frog<br>legs, spicy beef, spicy tripe, Chinese brocolli,<br>amazing eggplant,... Almost everything we tried<br>was delicious.More"], ["We visited with a large group and with an individual<br>who lives in China. She described Golden Harbor<br>as a combination of many local restaurants in<br>China. I have always thought the restaurant was<br>very good and our guest confirmed that feeling."], ["Old-fashioned Chinese family restaurant.  You fill<br>out a slip with your orders, give it to the cashier,<br>and bus your own food.  Portions large, food<br>very good."], ["They have two menus, one for your standard American<br>Chinese food, and one for Authentic Chinese/Taiwanese<br>food. Unusual ordering system, but it gets<br>the job done. Portions are huge. The authentic<br>section is very comparable to Taiwanese street<br>food. Overall, really good."], ["The food is exquisite: fresh, organic (many ingredients),<br>and tasty. The best Chinese food I have<br>ever had in central Illinois. Though most dishes<br>are pricey, you will surely return for more."], ["We\u2019ve been eating here for years and the food is fast<br>and delicious.  Recently the prices have been<br>going up.  Now it seems like the average is close<br>to $18 a dish.  Portions are good, but still.<br> Also they charge a plate cleaning fee."], ["They have way too many dishes, so hard to select.....they<br>are all good if you like real chinese style<br>food.  once you select, you give number to<br>cashier and take number to your table.  They charge<br>$1 per each person for cleaning fee, no additional...tips<br>required.  You can choose white<br>or fried rice when you pay for the food at the<br>cashier.  They also provide cash discount vs. cardMore"], ["Very large group/family oriented restaurant with a<br>huge menu.  Our food was delivered to our table<br>within minutes.  Very tasty.  Place filled with<br>locals and lots of families.  Lots of leftovers.<br> Good experience."], ["the best Chinese in Champaign-Urbana.....very fresh<br>and many choices on the menue....highly recommend."], ["Great chi ese food. Try the whole fish and some spicy<br>dish. The home made tofu was impressive.  Many<br>many choices and not sure how the chef can cook<br>so many different dishes"], ["I've heard so much about Golden Harbor and it lived<br>up to all expectations. What is really surprising<br>is that the restaurant has a very large menu<br>and has still been able to maintain its quality.<br>We came in a big group and tried a...several<br>dishes, including sichuan type dry fish, frog<br>legs, spicy beef, spicy tripe, Chinese brocolli,<br>amazing eggplant,... Almost everything we tried<br>was delicious.More"], ["We visited with a large group and with an individual<br>who lives in China. She described Golden Harbor<br>as a combination of many local restaurants in<br>China. I have always thought the restaurant was<br>very good and our guest confirmed that feeling."], ["Old-fashioned Chinese family restaurant.  You fill<br>out a slip with your orders, give it to the cashier,<br>and bus your own food.  Portions large, food<br>very good."], ["They have two menus, one for your standard American<br>Chinese food, and one for Authentic Chinese/Taiwanese<br>food. Unusual ordering system, but it gets<br>the job done. Portions are huge. The authentic<br>section is very co ...

# %% [markdown]
# ## Now you try!
# Websites that were specifically built for web scraping practice: http://toscrape.com/
#
# **Exercise**: Get the book titles, price, and availability from all books on this site: http://books.toscrape.com/
#
# Hint: The site has a piece of text at the top telling you how many results there are in total, which might help you determine how to write your loop to go through pages (and yes, there are also pages on this site; the format for accessing each page is pretty simple though).

# %%
# Your code here!

# %% [markdown]
# ## Other honorable mentions
#
# There are other libraries that can do more (or less) for you in terms of webscraping, and here are some of them:
#
# - Scrapy
# - MechanicalSoup
# - Selenium
#
# Web scraping is overall a great tool if an API is not available for accessing data from a website, but make sure that you are abiding by the rules of the internet and not DDOSing anybody unintentionally.
